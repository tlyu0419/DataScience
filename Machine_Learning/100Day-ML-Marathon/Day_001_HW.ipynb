# %% [markdown]
# # 作業1
# Kaggle競賽題目：[Microsoft Malware Prediction: Can you predict if a machine will soon be hit with malware?](https://www.kaggle.com/c/microsoft-malware-prediction)
# 這項Kaggle競賽旨在探討資訊安全的議題。
# 在當今社會中，小至民眾，乃至企業、政府等等的生活、辦公都是透過電腦、行動裝置等資訊設備進行處理。然而在資訊設備帶給我們便利的過程中，也伴隨著受到病毒、等惡意程式的威脅。稍有不慎就會造成莫大的損失。因此如何避免電腦、行動裝置受到惡意程式的攻擊就成為日益重要的議題。
# 這份資料是由Microsoft提供的資料集，其中包含了電腦作業系統、防毒軟體的版本資訊、預設的瀏覽器...等等共81項參數。
# 是運用訓練集資料建立監督式的模型，並將模型套用在測試集資料，最終會從AUC的角度來作為衡量成績的指標。

# %% [markdown]
# # 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題：
# 由於車隊的主要營收來自於「載客的數量」，因此我會將業績的指標定義為「載了多少乘客」，並設法提升車隊/司機的載客率作為主要目標。
# 要提升載客率，必須分析資源配置的問題，當某地區/時間客戶的需求量較大時，我們需要配置較多的司機，如此才能獲取最多利潤，反之則會變成資源浪費。另一方便我會檢視如何讓資源的效益最大化，若只賺取客戶「去程」的車資，則「回程」的時間與油料都會變成浪費，因此也需要盡可能媒合兩個「去程」成為「來回」程的接送。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 為了要了解各區域、各時間的客戶動線，我們可以與電信公司合作，共同分析客戶的手機信號資料。由於手機是現代人的隨身物品，並且手機定期會回傳資料至最近的基地台。因此我們可以把手機的位置當作是客戶的所在位置。接著搭配客戶的移動路徑、時間等資訊，就可以協助車隊找出資源配置與讓資源效益最大化的重要參考資料。
# 另外客戶使用的手機廠牌、年齡、性別、行動裝置數量...等等也都可能會與客戶的搭乘意願有關連性。這也可以在分析中進行額外的檢視。
# 3. 蒐集而來的資料型態為何
# 客戶的年齡、行動裝置數量等屬於integer的資料，手機廠牌、性別則屬於類別的資料，而客戶的移動路徑，距離則屬於numeric的資料。
# 4. 你要回答的問題，其如何評估
# 將目標車隊司機區分為實驗組與對照組，其中實驗組按照分析後的建議作為載客的策略，而對照組則按照傳統的方式接送客戶。在進行一段時間後，我們就可以比較兩個組別在載客率上是否有顯著的差異。若實際樣本夠多，我們還可以將實驗組區分為多個小組，並實施多種載客策略，進行更細緻的比較。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, y_hat):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - y_hat)**2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 282.800

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 282.800
# The Mean absolute error is 28562.833
