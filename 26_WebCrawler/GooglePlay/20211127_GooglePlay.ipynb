# %%
# !pip install google_play_scraper
# Out:
# ...
#      |████████████████████████████████| 52 kB 550 kB/s eta 0:00:01
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.2-py3-none-any.whl size=24380 sha256=ffc59db8d181315b26f361df8a9473a26608b07c80aab04c5126e28159ae16c4
#   Stored in directory: /home/tlyu0419/.cache/pip/wheels/b8/72/fa/8c7abdd259a9e1039b88e2c89c2b4f1282bdf32e3e916e7cb1
# Successfully built google-play-scraper
# ...

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.netflix.mediaclient',
    sleep_milliseconds=0.5, # defaults to 0
    # lang='en', # defaults to 'en'
    # country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    # filter_score_with=5 # defaults to None(means all score)
)

# %%
len(result)
# Out:
# 1194

# %%
# result

# %%
import requests
import pandas as pd

# %%
url = 'https://www.twse.com.tw/exchangeReport/MI_5MINS_INDEX'
resp = requests.get(url)
resp.json().keys()
# Out:
# dict_keys(['stat', 'date', 'title', 'fields', 'data', 'notes'])

# %%
pd.DataFrame(data=resp.json()['data'],
            columns=resp.json()['fields'])
# Out:
#             時間  發行量加權股價指數  未含金融保險股指數    未含電子股指數  未含金融電子股指數   水泥類指數     食品類指數  \
# 0     09:00:00  17,642.52  15,340.82  19,670.12  16,658.26  182.31  1,871.11
# 1     09:00:05  17,686.12  15,382.48  19,700.64  16,691.19  182.31  1,878.35
# 2     09:00:10  17,702.31  15,396.74  19,706.67  16,692.64  181.72  1,878.14
# 3     09:00:15  17,707.17  15,400.15  19,723.09  16,707.51  181.72  1,878.07
# 4     09:00:20  17,721.37  15,413.40  19,728.66  16,711.81  181.69  1,878.86
# ...        ...        ...        ...        ...        ...     ...       ...
# 3236  13:29:40  17,658.09  15,353.57  19,710.65  16,698.06  180.00  1,879.45
# 3237  13:29:45  17,658.09  15,353.57  19,710.65  16,698.06  180.00  1,879.45
# 3238  13:29:50  17,658.09  15,353.57  19,710.65  16,698.06  180.00  1,879.45
# 3239  13:29:55  17,658.09  15,353.57  19,710.65  16,698.06  180.00  1,879.45
# 3240  13:30:00  17,654.19  15,348.32  19,711.76  16,694.26  180.16  1,879.93
#
# ...

# %%
pd.date_range('20')

# %%
url = 'https://www.twse.com.tw/exchangeReport/MI_5MINS_INDEX?response=json&date=20211124'
resp = requests.get(url)
resp.json().keys()
# Out:
# dict_keys(['stat', 'date', 'title', 'fields', 'data', 'notes'])

# %%
# Out:
# '20211125'

# %%
ndf = pd.DataFrame(data=resp.json()['data'],
                   columns=resp.json()['fields'])
ndf['DATE'] =resp.json()['date']
ndf
# Out:
#             時間  發行量加權股價指數  未含金融保險股指數    未含電子股指數  未含金融電子股指數   水泥類指數     食品類指數  \
# 0     09:00:00  17,666.12  15,376.91  19,504.43  16,505.25  184.08  1,864.95
# 1     09:00:05  17,680.16  15,387.71  19,532.86  16,528.84  184.04  1,864.58
# 2     09:00:10  17,680.29  15,387.63  19,545.80  16,543.68  184.02  1,869.11
# 3     09:00:15  17,666.91  15,372.26  19,550.34  16,541.03  183.48  1,866.46
# 4     09:00:20  17,676.30  15,380.28  19,565.32  16,554.82  183.63  1,866.37
# ...        ...        ...        ...        ...        ...     ...       ...
# 3236  13:29:40  17,645.67  15,341.89  19,677.95  16,660.46  182.32  1,873.10
# 3237  13:29:45  17,645.67  15,341.89  19,677.95  16,660.46  182.32  1,873.10
# 3238  13:29:50  17,645.67  15,341.89  19,677.95  16,660.46  182.32  1,873.10
# 3239  13:29:55  17,645.67  15,341.89  19,677.95  16,660.46  182.32  1,873.10
# 3240  13:30:00  17,642.52  15,340.82  19,670.12  16,658.26  182.31  1,871.11
#
# ...
