# %% [markdown]
# - 要用 F12 的檢查功能找API
#     - offset 是以80為單位去抓產品清單資料
# - 產品連結是https://goods.ruten.com.tw/item/show? + ID
# - 商品描述藏在以下的連結中，但我們並不知道當中的k參數、o參數要怎麼設定，
#     https://goods.ruten.com.tw/item/goods_comments.php?id=22013384838237&k=20e83a8b&o=1591923102
# - 商品描述要加refer 才能request到資料
#
# 還好查詢過後可以在原先的 descriptionUrl 中找到，這時候我們就可以透過這個資訊抓資料囉!

# %%
import re
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent':'GoogleBot'}

# %%
# 商品分類
cateid = '001100020027'
pages = 50

prodids = []

for page in list(range(1, pages)):
    offset = 1 + 80*page
    url = 'https://rtapi.ruten.com.tw/api/search/v3/index.php/core/prod?cateid={}&sort=rnk%2Fdc&offset={}&limit=80&2653512&_callback=jsonpcb_CoreProd'.format(cateid, offset)
    resp = requests.get(url, headers=headers)
    data = re.sub(r'try\{jsonpcb_CoreProd\(|\);\}catch\(e\)\{if\(window.console\)\{console.log\(e\);\}\}','', resp.text)
    for prod in json.loads(data)['Rows']:
        prodids.append(prod['Id'])
    prodids = list(set(prodids))
    print('There are {} prods in list.'.format(len(prodids)))
# Out:
# There are 80 prods in list.
# There are 160 prods in list.
# There are 240 prods in list.
# There are 320 prods in list.
# There are 400 prods in list.
# There are 480 prods in list.
# There are 560 prods in list.
# There are 640 prods in list.
# There are 720 prods in list.
# There are 800 prods in list.
# There are 880 prods in list.
# There are 960 prods in list.
# There are 1040 prods in list.
# There are 1120 prods in list.
# There are 1200 prods in list.
# There are 1280 prods in list.
# There are 1360 prods in list.
# There are 1440 prods in list.
# There are 1520 prods in list.
# There are 1600 prods in list.
# There are 1680 prods in list.
# There are 1760 prods in list.
# There are 1840 prods in list.
# There are 1920 prods in list.
# There are 2000 prods in list.
# There are 2080 prods in list.
# There are 2160 prods in list.
# There are 2240 prods in list.
# There are 2320 prods in list.
# There are 2400 prods in list.
# There are 2480 prods in list.
# There are 2560 prods in list.
# There are 2640 prods in list.
# There are 2720 prods in list.
# There are 2800 prods in list.
# There are 2880 prods in list.
# There are 2960 prods in list.
# There are 3040 prods in list.
# There are 3120 prods in list.
# There are 3200 prods in list.
# There are 3280 prods in list.
# There are 3360 prods in list.
# There are 3440 prods in list.
# There are 3520 prods in list.
# There are 3600 prods in list.
# There are 3680 prods in list.
# There are 3760 prods in list.
# There are 3840 prods in list.
# There are 3920 prods in list.

# %%
df = []
for i, prodid in enumerate(prodids):
    print('='*60)
    print('Dealing with {}: {}'.format(i, prodid))
    headers = {'User-Agent':'GoogleBot'}
    url = 'https://goods.ruten.com.tw/item/show?' + prodid
    resp = requests.get(url, headers=headers)
    soup = BeautifulSoup(resp.text)
    data1 = json.loads(soup.findAll('script',{'type':'application/ld+json'})[0].text)
    data2 = json.loads(soup.findAll('script',{'type':'application/ld+json'})[1].text)
    data3 = json.loads(soup.findAll('script',{'type':'application/ld+json'})[2].text)
    # 產品名稱
    print('名稱：', data1['name'])
    # 幣別
    print('幣別：', data1['offers']['priceCurrency'])
    # 價格
    print('價格：', data1['offers']['price'])
    # 商品分類
    print('商品分類：', r'/'.join([i['item']['name'] for i in data3['itemListElement']]))
    # 商品描述
    descurl = re.findall(r'goods_comments.php\?id=.*?o=[0-9]{1,}',resp.text)[0]
    descurl = re.sub('&amp;','&',descurl)
    descurl = 'https://goods.ruten.com.tw/item/' + descurl
    headers = {'User-Agent':'GoogleBot',
               'Referer': 'https://goods.ruten.com.tw/item/show?{}'.format(prodid)}
    resp2 = requests.get(descurl, headers=headers)
    soup2 = BeautifulSoup(resp2.text)
    desc = ' '.join(i.text for i in soup2.findAll('p'))
    
    ndf = pd.DataFrame([{'name': data1['name'],
                         'description':data1['description'],
                         'productId':data1['productId'],
                         'brand_name':data1['brand']['name'],
                         'priceCurrency':data1['offers']['priceCurrency'],
                         'price':data1['offers']['price'],
                         'contentLocation':data2['contentLocation'],
                         'item_name':r'/'.join([i['item']['name'] for i in data3['itemListElement']]),
                         'describe':desc}])
    df.append(ndf)

df = pd.concat(df, ignore_index=True)
df
# Out:
# ============================================================
# Dealing with 0: 30202516960374
# Acer NX.VK9AA.002
# TWD
# 58137
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 1: 30202475013175
# HP 8460W DSC WLCD HD+ FLT WCAM RCTO UNIT - 650693-001
# TWD
# 3422
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 2: 30202467452500
# Latitude•4GB•Intel i5-4200M 2.5 GHz•W10P•Silver•HD HD•500GB•6Cell BatteryWh•DVD
# TWD
# 14991
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3: 30201122038754
# Microsoft Surface Pro 1st Gen 1514 i5-3317U 1.7GHz 128GB SSD 4GB Win 10 Pro
# TWD
# 4869
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 4: 30202408707171
# WILLIAMS BLUE BIRD 2 ( BB2 ) CPU With MAYAN SUN SOFTWARE
# TWD
# 10964
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 5: 30201274725137
# Avita Clarus 14&quot; Laptop Intel i5-7Y54 1.2GHz 8GB RAM -BOOTS -RR
# TWD
# 5192
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 6: 30202416479097
# Dell Latitude E6410 Core i5 / PARTS OR REPAIR/ WINDOWS 10 PROF
# TWD
# 3880
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 7: 30202545770881
# Lenovo 20S00030US Ts T14 G1 I5 8g 256g W10p
# TWD
# 52229
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 8: 30202400068870
# NEW HP 7MU69UT#ABA ProBook 455R G6 Notebook PC 3500U 15.6-in 8GB 500GB Radeon
# TWD
# 25855
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 9: 30202484949881
# Dell Latitude E4300 C2D 2.4GHz 4gb 320Gb Windows 10 Pro
# TWD
# 2513
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 10: 30202524113856
# Dell XPS 13 9343 13.3&quot; Notebook Intel Core i5-5200U 4GB 128GB FHD 1080p Win 10!
# TWD
# 14137
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 11: 30202441857860
# Lenovo ThinkPad L490 20Q5001QUS 14 Notebook - 1920 x 1080 - + Office 365 Bundle
# TWD
# 36699
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 12: 30202435936074
# Rare Vintage Toshiba Satellite 2230CDS Laptop Windows 98 SE Gaming, Works Great
# TWD
# 4053
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 13: 30202544851172
# HP EliteBook 840 G1 14&quot; Core i7-4600U 2.1GHz 500GB 16GB Touchscreen Win10 Home
# TWD
# 9079
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 14: 30202392636769
# Hp ProBook 4525s Athlon II P340 Dual Core 2.2GHz 2GB RAM No HDD
# TWD
# 3010
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 101: 30202480798654
# Dell DNDM6 Latitude 5290 Notebook with Intel i5-8350U, 8GB 500GB HDD, 12.5&quot;
# TWD
# 25132
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 102: 30202539109936
# Dell Latitude E5470 | Intel Core i7 | 2.70GHz | 8GB RAM | 500GB SSHD | Win10 Pro
# TWD
# 13163
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 103: 30202425073862
# Lenovo ThinkPad X140e 11.6&quot; AMD A4-5000 Quad Core 8GB/128GB SSD+Charger&amp;Battery
# TWD
# 3927
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 104: 30202546581073
# HP Mini 2102 (Intel Atom N450 1.66GHz, 2GB RAM, 160GB HD, Win 10, WiFi)
# TWD
# 2670
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 105: 30202458879132
# Dell Latitude e6520 Quad Core i7 2.4Ghz, 8gb, nVidia NVS, 500gb HDD Win 10 READ
# TWD
# 6280
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 106: 30202544746030
# 210-AETM Dell Latitude E7470 i7-6600U 8GB 256GB SSD 14&quot; QHD Touch 2560x1440 Ship
# TWD
# 17562
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 107: 21840725415368
# IBM PS/55  5535S 日文攜帶型電腦
# TWD
# 16000
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 108: 30202481177780
# Dell XPS 13 7390 13.3'' FHD Laptop Intel i7-10710U CPU,8GB RAM,512GB SSD, Silver
# TWD
# 43668
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 109: 30202503144790
# Lenovo Yoga 730 15.6&quot; Laptop Intel Core i5 8GB 256GB Windows 10 - Gray
# TWD
# 18997
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 110: 30202510648359
# Panasonic Toughbook CF31 MK2 2.4Ghz i5 z 8GB 256SSD DVD Touch WIN10 64
# TWD
# 20420
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 111: 30202471181717
# NEW HP 7QT62UT#ABA mt21 14&quot; Thin Client Notebook - 1920 x 1080 Celeron 3867U 8
# TWD
# 22111
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 112: 30202480091560
# Dell 3K8JP Latitude 3590 Notebook with Intel i7-8550U, 8GB 500GB HDD, 15.6&quot;
# TWD
# 62832
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 113: 21921521325025
# 網樂購 商務 Surface Laptop 2 I7-8650U/8G/UHD620/256GSSD LQR-00018
# TWD
# 54300
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 114: 30202497486296
# 2 Dell Latitude 13.3&quot; E4300 Intel Core 2 Duo No RAM No HDD For PARTS ONLY
# TWD
# 1759
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 115: 30202533441759
# HP Pavilion dv6 500 GB Hard Drive, Intel i7, 8GB Ram,with finger print scanner
# TWD
# 9110
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 116: 30202524121675
# Lenovo IdeaPad 3 15.6 Laptop Intel Core i3 8GB Memory 256GB SSD Windows 10 Blue
# TWD
# 12723
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 117: 30202458146870
# HP Envy x360 15-dr000 Convertible Laptop Touch 15t 15.6&quot; i7-8565u 16GB 512GB SSD
# TWD
# 25046
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 118: 30202456634038
# New Lenovo Thinkpad P53s,i7-8565U,FHD,Quadro P520,16GB,1TB NVMe,Bklit,3Yrs Wty
# TWD
# 48663
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 119: 30202225997270
# Google PixelBook C0A Chromebook i5-7Y57 1.20GHz 128GB SSD 8GB RAM - READ #48276
# TWD
# 12587
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 120: 30202509046449
# Lenovo ThinkPad T480 20L5004HUS 14 Notebook - 1366 x 768 - + Office 365 Bundle
# TWD
# 27121
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 121: 30184916340829
# Microsoft Surface Go 10&quot; Touchscreen Intel Pentium Gold 4GB RAM 64GB SSD Win 10
# TWD
# 10022
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 206: 30202441576521
# HP Envy 17t-ce100 Laptop PC 17 17.3&quot; i7-10510u Quad 16GB 1TB SSD 4GB GeF MX250
# TWD
# 29137
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 207: 30202518842656
# Lenovo ThinkPad Yoga 11e 5th Gen 20LM000YUS 11.6 Touchscreen 2 in 1 Notebook -
# TWD
# 24990
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 208: 30201695826697
# Panasonic CF-SX2 TOUGHBOOK core i5 3320M 2.6Ghz 8 GB RAM THE BIOS IS LOCKED
# TWD
# 6858
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 209: 30202429731957
# Samsung Chromebook 3 11.6&quot; (16GB, Intel Atom X5, 1.04GHz, 2GB) Laptop - Night...
# TWD
# 6252
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 210: 30202505563371
# HP Pavilion DM4 Notebook pC
# TWD
# 4712
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 211: 30202123943188
# HP Chromebook x2 2-in-1 12.3&quot; Touch 12-f001tu Core 4415Y 4GB 32GB laptop + pen
# TWD
# 9268
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 212: 30202510469136
# Dell Inspiron 17 3785 Laptop, 17.3&quot;, AMD Ryzen 3, 8GB RAM, 1TB HDD, Win10
# TWD
# 18850
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 213: 30202445922632
# NEW ! KENWOOD P-5D Turntable Belt&lt;FAST SHIPPING>D005XX
# TWD
# 580
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 214: 30202412800282
# C6666 Dell Precision 3520 Motherboard with i5-7440H CPU Quadro M620 Graphics
# TWD
# 18995
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 215: 30202411401255
# ThinkPad•HD HD•500GB•8GB•Black•lithiumCell LithiumWh•Refurbished•WARRANTY
# TWD
# 16179
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 216: 30201379034057
# Razer Blade 15 i7-8750H 16GB 512GB SSD 15.6&quot; FHD 144Hz NVIDIA RTX 2060 White
# TWD
# 49321
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 217: 30202489080242
# Acer Swift 13.3&quot; Full HD Intel Quad Core N4200 2.5GHz 4GB 64GB eMMC Webcam
# TWD
# 15614
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 218: 30202501000700
# Omen by HP 2019 15-Inch Gaming Laptop, Intel i7-9750H Processor, GeForce RTX...
# TWD
# 51805
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 219: 30202492242538
# Lenovo 20T20022US Tp X13 G1 W10p I5 16gb 256gb 3yr
# TWD
# 50250
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 220: 30202440546088
# SAMSUNG CHROMEBOOK 3 11.6 INTEL CELERON 1.60 GHZ 4GB RAM LAPTOP BLACK
# TWD
# 3739
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 221: 30202435791578
# Dell Latitude D630 D620 Intel Core 2 Duo, 80GB, 2G, WiFi, Windows 7, Optical Dri
# TWD
# 3141
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 222: 30202417576254
# Latitude 15” 3000 3500•i3-8145U•W10P•4GB•HD 15.6&quot;•512GB•M2•NVME•Refurbished
# TWD
# 27857
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 223: 30202415702747
# Acer 14&quot; HD Chromebook,Intel Quad-Core 2GHz,4GB Memory,32GB eMMC+Sleeve Bag HP
# TWD
# 8781
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 224: 30202515651820
# Dell Precision M3800 2.3ghz quad i7-4712HQ 16gb 256gb 1920x1080 FHD TOUCH K1100M
# TWD
# 11310
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 225: 30202502061438
# Dell Precision 7530 15.6&quot; Mobile Workstation - Core i7-8850H 32GB 512GB SSD
# TWD
# 34401
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 226: 30202495699155
# Dell Latitude E5520 15.6” Laptop Core i3-2310M, 4 GB RAM, 500 GB HDD w/Adapter
# TWD
# 4398
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3880: 30202459098406
# HP ProBook x360 11 G6 EE Notebook PC
# TWD
# 31124
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3881: 30202418671408
# HP ProBook x360 11 G6 EE 11.6 Touchscreen 2 in 1 Notebook - + Office 365 Bundle
# TWD
# 25328
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3882: 30202522616537
# LG R580-K.APC4BE1 Intel Core 2 Duo T6500 2.1 GHz 4 GB RAM 500 GB HDD Win10 Pro
# TWD
# 3141
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3883: 30184960409509
# ASUS Transformer Book T100TAM 10.1″ Notebook - Intel Z3775 1.46 GHz - 2 GB RAM -
# TWD
# 3110
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3884: 30202482946392
# Lenovo Legion Y540 Gaming Laptop: Core i7-9750H, 17.3&quot; Full HD 144Hz 1TB SSD
# TWD
# 41127
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3885: 30202546644466
# Dell Latitude 14.1&quot; Laptop Computer PC i3 8GB 256GB SSD HDMI Wifi DVD Windows 10
# TWD
# 5967
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3886: 30202537927820
# HP Remarketing 9VC43U8R#ABA Pavilion 15-cs2000 Notebook 15.6-in REFURB PAV 15.6
# TWD
# 21582
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3887: 30202461999230
# Brand New Dell 12.5&quot; Latitude 5290 Notebook - i5 - 8GB RAM 256GB SSD
# TWD
# 25132
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3888: 30202469783497
# HP 15.6” HD (TouchScreen) Laptop Intel Core i3-8145U 3.90GHz 8GB 1TB HD BT Win10
# TWD
# 12878
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3889: 30202431640072
# Dell Latitude E5470 Laptop i7 16GB RAM 14&quot; 256GB SSD Windows 10 Pro
# TWD
# 15708
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3890: 30202410807502
# LENOVO - TOPSELLER THINK 20N8006XUS TS THINKPAD E490 I5-8265U 1.6G
# TWD
# 30646
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3891: 30202456832690
# HP ProBook 650 G5 15.6 Touchscreen Notebook - 1920 x 1080 - Core i5 i5-8365U -
# TWD
# 42264
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3892: 30202518937224
# Inspiron 17” 3000 3780•W10H•1TB•8GB•Black•HD+ 17.3&quot;•TOUCH
# TWD
# 17320
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3893: 30201152930590
# OptiPlex 7000 7070 Micro•W10P•Intel 9th i5-9500T•M2•NVME•16GB•Refurbished
# TWD
# 31234
# 露天拍賣/ 電腦、電子、周邊 / 電腦周邊設備 / 其他電腦周邊設備
# ============================================================
# Dealing with 3894: 30202539688017
# T440S•14&quot;•12GB•Intel i5-4200U 1.60 GHz•W10P•256GB•Refurbished•WARRANTY
# TWD
# 20627
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3895: 30202547349672
# Microsoft - Surface Laptop 3/15&quot; Touch/AMD Ryzen 5 3580U/16GB/256GB SSD/Black
# TWD
# 61010
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3896: 30202491394287
# ON-SALE--IBM/Lenovo ThinkPad z60m/ PARTS AND REPAIR/ $80.00
# TWD
# 2388
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3897: 30202547861727
# HP Compaq Presario CQ60-615DX Laptop
# TWD
# 3456
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3898: 30202527080717
# HP EliteBook 840 14&quot; Core i5-5200U 8GB RAM 256GB SSD Win 10
# TWD
# 8639
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3899: 30202402087794
# Panasonic Toughbook CF-18 MK2. TO MK4 1.10 MHz,60GB HD,NOTOUCH, WINDOWS XP PRO
# TWD
# 3770
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3900: 21942388892545
# 5Cgo【聯強】lenovo ThinkPad T490 系列 (I7) 512GB SSD  N2S01P00 含稅
# TWD
# 999999
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3901: 30202394232910
# NEW Lenovo IdeaPad 330s 15.6&quot; HD AMD Ryzen 5 8GB DDR4 256GB SSD Webcam BT Win 10
# TWD
# 18221
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3902: 30202459144194
# Tecra•Intel i5-6300U 2.40 GHz•14&quot;•W10P•8GB•128GB•Refurbished•WARRANTY
# TWD
# 16543
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3903: 30202445844792
# HP 15-f271wm 15.6 Laptop PC -Intel Pentium N3540 Processor / 4GB Memory / 500GB
# TWD
# 10995
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3904: 30202403221379
# HP ProBook 450 G6 15.6 Notebook - 1920 x 1080 - Core i5 i5- + Office 365 Bundle
# TWD
# 32796
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3905: 30202510601189
# Dell Inspiron 13 7000 13.3&quot;&quot; Laptop AMD Ryzen 7 12GB 256GB Win 10 - Gray
# TWD
# 18362
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3906: 30202507670686
# EliteBook•8GB•Intel i7-6600U 2.60 GHz•W10H•256GB•12.5&quot;•Refurbished•WARRANTY
# TWD
# 23119
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3907: 30202470262862
# Panasonic Toughbook CF-31 MK4 Core i5 2.7GHz 16GB 240GB SSD Touchscreen Win 10
# TWD
# 21834
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3908: 30202488678569
# Lot of 3 HP Probook 6555B Laptops - 4GB RAM
# TWD
# 5184
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3909: 30202447087142
# HP 15.6&quot; Silver Laptop 15-da0053wm Intel i5-8250U 1.60GHz/8GB/1TB/16GB Optane A-
# TWD
# 12158
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3910: 30202404780538
# Dell Latitude 12&quot; E6230 i7-3520M 2.9GHz 4GB 256GB SSD Backlit WiFi Win 7 Laptop
# TWD
# 6597
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3911: 30202485277561
# Microsoft Surface Pro 4 8GB Windows 10 Pro 256GB SSD Intel Core i5
# TWD
# 10367
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3912: 30202390431951
# Microsoft Surface Go 128GB SSD, 8GB RAM, Silver MCZ-00001 Over $600 Package
# TWD
# 13652
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3913: 30202538056228
# MT PC LENOVO ThinkCentre M73 Intel i3-4130. 4GB/500GB, No OS &quot;A&quot;
# TWD
# 4083
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3914: 30202428333257
# HP 15-dw0043dx 15.6&quot; Touch HD- Core i5 / 8GB memory 128GB SSD Pre Owned laptop
# TWD
# 14137
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3915: 30202525425808
# Lenovo IdeaPad 530S AMD Ryzen 5 2500U 2.0GHz 14&quot; 8GB 256GB SSD Windows 10
# TWD
# 16251
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3916: 30202456803036
# Dell Latitude D610 1.6GHz Intel Pentium M 1.GB RAM 40GB Hard Drive Lubuntu 18.10
# TWD
# 2670
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3917: 30202452257057
# Custom Build your Panasonic Toughbook CF-30 Rugged Laptop Military Non-Touch
# TWD
# 16922
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3918: 30202512726224
# Toshiba Tecra 730XCDT Laptop
# TWD
# 2513
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ============================================================
# Dealing with 3919: 30202416933362
# Latitude•8GB•480GB•W10H•HD HD•Refurbished•DVD•ionCell IonWh•WARRANTY
# TWD
# 14787
# 露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
#                                                    name  \
# 0                                     Acer NX.VK9AA.002
# 1     HP 8460W DSC WLCD HD+ FLT WCAM RCTO UNIT - 650...
# 2     Latitude•4GB•Intel i5-4200M 2.5 GHz•W10P•Silve...
# 3     Microsoft Surface Pro 1st Gen 1514 i5-3317U 1....
# 4     WILLIAMS BLUE BIRD 2 ( BB2 ) CPU With MAYAN SU...
# ...                                                 ...
# 3915  Lenovo IdeaPad 530S AMD Ryzen 5 2500U 2.0GHz 1...
# 3916  Dell Latitude D610 1.6GHz Intel Pentium M 1.GB...
# 3917  Custom Build your Panasonic Toughbook CF-30 Ru...
# 3918                       Toshiba Tecra 730XCDT Laptop
# 3919  Latitude•8GB•480GB•W10H•HD HD•Refurbished•DVD•...
#
#                                             description       productId  \
# 0     直購價：58,137元。物品狀態：全新。支付方式包含PChomePay支付連。(302025...  30202516960374
# 1     直購價：3,422元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(30...  30202475013175
# 2     直購價：14,991元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(3...  30202467452500
# 3     直購價：4,869元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(30...  30201122038754
# 4     直購價：10,964元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(3...  30202408707171
# ...                                                 ...             ...
# 3915  直購價：16,251元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(3...  30202525425808
# 3916  直購價：2,670元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(30...  30202456803036
# 3917  直購價：16,922元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(3...  30202452257057
# 3918  直購價：2,513元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(30...  30202512726224
# 3919  直購價：14,787元。物品狀態：請參考商品說明。支付方式包含PChomePay支付連。(3...  30202416933362
#
#                    brand_name priceCurrency  price  contentLocation  \
# 0         interloper-com@ebay           TWD  58137        US,Dallas
# 1              wicky_dog@ebay           TWD   3422       US,Syosset
# 2         swingcomputers@ebay           TWD  14991  US,Redwood City
# 3       powercellularinc@ebay           TWD   4869    US,Northbrook
# 4        babydoll_gaming@ebay           TWD  10964       US,Houston
# ...                       ...           ...    ...              ...
# 3915            highlido@ebay           TWD  16251        US,Linden
# 3916  nookdesignbysierra@ebay           TWD   2670      US,Caliente
# 3917      rugged.laptops@ebay           TWD  16922   CA,Scarborough
# 3918           david6007@ebay           TWD   2513          US,York
# 3919      swingcomputers@ebay           TWD  14787  US,Redwood City
#
#                            item_name  \
# 0     露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 1     露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 2     露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 3     露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 4     露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# ...                              ...
# 3915  露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 3916  露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 3917  露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 3918  露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
# 3919  露天拍賣/ 電腦、電子、周邊 / 筆記型電腦 / 商用筆電
#
#                                                describe
# 0
# 1
# 2
# 3
# 4     ***Check out my Ebay Store   /babydollgamingmo...
# ...                                                 ...
# 3915    Lenovo IdeaPad 530S  AMD Ryzen 5 2500U 2.0GH...
# 3916
# 3917
# 3918
# 3919
#
# [3920 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3920 entries, 0 to 3919
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             3920 non-null   object
#  1   description      3920 non-null   object
#  2   productId        3920 non-null   object
#  3   brand_name       3920 non-null   object
#  4   priceCurrency    3920 non-null   object
#  5   price            3920 non-null   object
#  6   contentLocation  3920 non-null   object
#  7   item_name        3920 non-null   object
#  8   describe         3920 non-null   object
# dtypes: object(9)
# memory usage: 275.8+ KB

# %%
df.to_excel('./RuTen.xlsx')
