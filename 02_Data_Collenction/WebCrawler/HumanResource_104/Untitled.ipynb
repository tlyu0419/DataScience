# %%
import pandas as pd
import os

# %%
df = pd.read_pickle('./data/data.pkl')
df
# Out:
#        jobType     jobNo                           jobName  \
# 0            1   5942139                   【野草居食屋】餐飲外場正職人員
# 1            2  10188632                       營運稽核專員(總公司)
# 2            0   8649563                              行政經理
# 3            0  11865617                     正職店員(台北公館秀泰店）
# 4            2   7490050      【すき家 SUKIYA】古亭店、公館店、東門店-儲備幹部
# ...        ...       ...                               ...
# 365568       3  11863235                            照顧管理專員
# 365569       3  11934429                 多那之高雄青年門市--正職早班人員
# 365570       3  11909038  行政專員 (工作地點:杜拜) (要敢在杜拜開車)(需要待過杜拜)
# 365571       3   8927462    文字線上客服專員 ( 桃園 )  ※ 月薪30K ~ 38K
# 365572       3  10007566                             安親班老師
#
#                           jobNameSnippet jobRole jobRo   jobAddrNo  \
# 0                        【野草居食屋】餐飲外場正職人員       1     1  6001001001
# 1                            營運稽核專員(總公司)       1     1  6001001001
# ...

# %%
df['link'] = df['link'].apply(lambda x: x['job'])
df
# Out:
#        jobType     jobNo                           jobName  \
# 0            1   5942139                   【野草居食屋】餐飲外場正職人員
# 1            2  10188632                       營運稽核專員(總公司)
# 2            0   8649563                              行政經理
# 3            0  11865617                     正職店員(台北公館秀泰店）
# 4            2   7490050      【すき家 SUKIYA】古亭店、公館店、東門店-儲備幹部
# ...        ...       ...                               ...
# 365568       3  11863235                            照顧管理專員
# 365569       3  11934429                 多那之高雄青年門市--正職早班人員
# 365570       3  11909038  行政專員 (工作地點:杜拜) (要敢在杜拜開車)(需要待過杜拜)
# 365571       3   8927462    文字線上客服專員 ( 桃園 )  ※ 月薪30K ~ 38K
# 365572       3  10007566                             安親班老師
#
#                           jobNameSnippet jobRole jobRo   jobAddrNo  \
# 0                        【野草居食屋】餐飲外場正職人員       1     1  6001001001
# 1                            營運稽核專員(總公司)       1     1  6001001001
# ...

# %%
df.drop_duplicates(['link']).to_pickle('C:/Users/TLYu0419/Desktop/JobsData.plk')

# %%
df = df.drop_duplicates(['link'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229182 entries, 0 to 365571
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   jobType         229182 non-null  object
#  1   jobNo           229182 non-null  object
#  2   jobName         229182 non-null  object
#  3   jobNameSnippet  229182 non-null  object
#  4   jobRole         229182 non-null  object
#  5   jobRo           229182 non-null  object
#  6   jobAddrNo       229182 non-null  object
#  7   jobAddrNoDesc   229182 non-null  object
#  8   jobAddress      229182 non-null  object
#  9   description     229182 non-null  object
#  10  optionEdu       229182 non-null  object
#  11  period          229182 non-null  object
#  12  periodDesc      229182 non-null  object
#  13  applyCnt        229182 non-null  object
#  14  applyDesc       229182 non-null  object
#  15  custNo          229182 non-null  object
# ...
