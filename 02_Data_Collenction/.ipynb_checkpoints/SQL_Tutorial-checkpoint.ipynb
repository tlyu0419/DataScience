# %% [markdown]
# # SQL Tutorial

# %% [markdown]
# ## import packages

# %%
import requests
import pandas as pd
import sqlite3

# %% [markdown]
# ## Prepare data
# -  [TSMC news on the udn website.](https://udn.com/news/index)

# %%
# df = []
# page = 1
# while True:
#     try:
#         url = f'https://udn.com/api/more?page={page}&id=search:台積電&channelId=2&type=searchword'
#         resp = requests.get(url)
#         ndf = pd.DataFrame(resp.json()['lists'])
#         df.append(ndf)
#         page = page+1
#     except:
#         print('Error and retry.')
#     if ndf.shape[0] < 20:
#         break
# df = pd.concat(df, ignore_index=True)
# df

# %%
# df['date'] = df['time'].apply(lambda x: x['dateTime'][:10])
# df['time'] = df['time'].apply(lambda x: x['dateTime'][11:])

# df = df.loc[:,['title', 'paragraph', 'cateTitle', 'date','time', 'url']]

# conn = sqlite3.connect('./data/tsmc.db')
# df.to_sql(con=conn, name='tsmc_news', if_exists='replace', index=False)

# %% [markdown]
# ## Connect to sqlite db

# %%
conn = sqlite3.connect('./data/tsmc.db')

# %% [markdown]
# ## Tutirial

# %%
# con = sqlite3.connect("test.sqlite")
# cur = con.cursor()
# # drop TABLE
# cur.execute("DROP TABLE IF EXISTS PhoneAddress")

# # create TALBE
# cur.execute('''CREATE TABLE PhoneAddress(
#             phone CHAR(10) PRIMARY KEY
#             , address TEXT
#             , name TEXT unique
#             , age INT NOT NULL)''')

# # insert
# cur.execute("INSERT INTO PhoneAddress VALUES('0912173381','United State','Jhon Doe',53)")
# cur.execute("INSERT INTO PhoneAddress VALUES('0928375018','Tokyo Japan','MuMu Cat',6)")
# cur.execute("INSERT INTO PhoneAddress VALUES('0957209108','Taipei','Richard',29)")
# cur.execute("SELECT phone,address FROM PhoneAddress")
# data = cur.fetchall()
# for rec in data:
#     print(rec[0], rec[1])

# %% [markdown]
# ### SELECT
# select all data in the table

# %%
query = '''
SELECT * 
FROM TSMC_NEWS 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2              電子股資金撤出 法人：台股上攻缺量
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                          ...
# 14258               曹興誠 強硬聲明展現擔當
# 14259              曹興誠,衝勁十足 能賺敢賺
# 14260            華碩董座施崇棠 捐台大5.4億
# 14261                 郭台銘送妻最後一程…
# 14262                在漫畫沃土 創動畫新潮
#
#                                                paragraph cateTitle  \
# 0      副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞
# 1      反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞
# 2      台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市
# 3      台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市
# 4      第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞
# ...                                                  ...       ...
# 14258  【記者陳令軒】  雙魚座個性的聯電董事長曹興誠，60大壽就在下周。受到蘇州和艦案影響，他挺身...      時事話題
# ...

# %% [markdown]
# ### LIMIT

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
LIMIT 5
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                        title  \
# 0      宣講公投案 賴副總統：三接攸關北部穩定供電
# 1  反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2          電子股資金撤出 法人：台股上攻缺量
# 3     外資小幅買超6.81億元 航空雙雄包辦前2名
# 4  林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
#
#                                            paragraph cateTitle        date  \
# 0  副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞  2021-11-24
# 1  反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞  2021-11-24
# 2  台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市  2021-11-24
# 3  台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市  2021-11-24
# 4  第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞  2021-11-24
#
#        time                                                url
# 0  20:56:04  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 1  20:40:04  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 2  20:05:12  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 3  19:55:10  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# ...

# %% [markdown]
# ### AS
# rename columns

# %%
query = '''
SELECT title AS NAME
    , paragraph AS ABBR
    , cateTitle AS CATEGORY
    , date as DATE
    , time AS TIME
    , url as URL
FROM TSMC_NEWS 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                             NAME  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2              電子股資金撤出 法人：台股上攻缺量
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                          ...
# 14258               曹興誠 強硬聲明展現擔當
# 14259              曹興誠,衝勁十足 能賺敢賺
# 14260            華碩董座施崇棠 捐台大5.4億
# 14261                 郭台銘送妻最後一程…
# 14262                在漫畫沃土 創動畫新潮
#
#                                                     ABBR CATEGORY        DATE  \
# 0      副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...       要聞  2021-11-24
# 1      反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...       要聞  2021-11-24
# 2      台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...       股市  2021-11-24
# 3      台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....       股市  2021-11-24
# 4      第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...       要聞  2021-11-24
# ...                                                  ...      ...         ...
# ...

# %% [markdown]
# ### ORDER BY

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
ORDER BY date 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                                       title  \
# 0                               在漫畫沃土 創動畫新潮
# 1                                郭台銘送妻最後一程…
# 2                           華碩董座施崇棠 捐台大5.4億
# 3                              曹興誠 強硬聲明展現擔當
# 4                             曹興誠,衝勁十足 能賺敢賺
# ...                                     ...
# 14258        東方領袖講座／政院副院長談全球減碳 沈榮津：綠色產業已成趨勢
# 14259                         三星、台積 赴美爆製程大戰
# 14260                          財部催動地方 課徵囤房稅
# 14261                          元大ESG高股息N 帶勁
# 14262  【星期五的月光曲－台積電文學沙龍75現場報導】侯延卿／放火的人，未燒之書
#
#                                                paragraph cateTitle  \
# 0      【記者錢欽青、于國華、梁玉芳】  問：電影「一一」故事裡吳念真演的主角，為了投資網路電玩，對...      時事話題
# 1      【記者林信昌／台北報導】 鴻海集團總裁郭台銘昨（31）日神情哀淒，送愛妻林淑如最後一程，她將...      時事話題
# 2      【記者喻文玟／台北報導】華碩電腦董事長、台大電機系校友施崇棠，個人捐五億四千萬元協助台大興建...      時事話題
# 3      【記者陳令軒】  雙魚座個性的聯電董事長曹興誠，60大壽就在下周。受到蘇州和艦案影響，他挺身...      時事話題
# 4      【記者詹惠珠、林宏文/台北】  聯電董事長曹興誠，在半導體業界一向被視為爭議性人物，但談到他...      時事話題
# ...

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
ORDER BY date DESC
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2              電子股資金撤出 法人：台股上攻缺量
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                          ...
# 14258               曹興誠 強硬聲明展現擔當
# 14259              曹興誠,衝勁十足 能賺敢賺
# 14260            華碩董座施崇棠 捐台大5.4億
# 14261                 郭台銘送妻最後一程…
# 14262                在漫畫沃土 創動畫新潮
#
#                                                paragraph cateTitle  \
# 0      副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞
# 1      反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞
# 2      台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市
# 3      台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市
# 4      第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞
# ...                                                  ...       ...
# 14258  【記者陳令軒】  雙魚座個性的聯電董事長曹興誠，60大壽就在下周。受到蘇州和艦案影響，他挺身...      時事話題
# ...

# %% [markdown]
# ### WHERE
# - =：等於
# - \>:大於
# - \<:小於
# - <>: 不等於
# - \>=: 大於等於
# - <=：小於等於

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE CATETITLE = '產經'
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                           title  \
# 0      出口商拋匯支撐 新台幣升1.6分收27.793元
# 1      台積電首設廠務學院設在中科 已培育逾500位新人
# 2      聯電、南茂等六家半導體及材材料 挺光洋科經營團隊
# 3         聯電等半導體大咖發聲明 挺馬堅勇續留光洋科
# 4     房市崩潰現前兆、台灣會失落30年？學者揭往事曝關鍵
# ...                         ...
# 3589         張忠謀宣布退休 外資：不捨！但非利空
# 3590       張忠謀無預警宣布退休 劉德音繼任新董事長
# 3591     這不是張忠謀首次宣布退休 竹科金融海嘯時回鍋
# 3592        張忠謀明年6月交棒劉德音 魏哲家任總裁
# 3593       張忠謀宣布明年六月退休 劉德音接任董事長
#
#                                               paragraph cateTitle        date  \
# 0     台股走跌，不過匯市部分外資偏向匯入，加上出口商月底有拋匯需求，新台幣兌美元今天收盤收27.7...        產經  2021-11-24
# 1     台積電（2330）今日對外說明，首設廠務學院在中科，同時該廠務學院今年已來已陸續培育逾500...        產經  2021-11-24
# 2     繼台積電力挺光洋科經團隊後，包括聯電、南茂、穩懋、晶技、錸寶、日揚科技等六家半導體及材料廠，...        產經  2021-11-24
# 3     光洋科（1785）最後買進日已經截止，接下來進入各自拉票階段，今現任光洋科經營團隊獲聯電（2...        產經  2021-11-24
# 4     近一年各地房價以驚人速度上漲，加上少子化加劇，不少人認為房市崩盤已出現前兆。萬一台灣房市泡沫...        產經  2021-11-24
# ...                                                 ...       ...         ...
# ...

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date >= '2021-01-01'
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2              電子股資金撤出 法人：台股上攻缺量
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                          ...
# 11704               企業綠能達標 要看二因素
# 11705       面板雙虎可望轉虧為盈 有機會恢復年度調薪
# 11706         中芯公布最新人事 董事名單仍有梁孟松
# 11707             跟進台積 世界先進加薪10%
# 11708    中芯國際公布最新董事名單 梁孟松仍任聯合CEO
#
#                                                paragraph cateTitle  \
# 0      副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞
# 1      反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞
# 2      台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市
# 3      台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市
# 4      第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞
# ...                                                  ...       ...
# 11704  「用電大戶條款」今（1）日上路，規定契約容量5,000瓩以上的用電大戶須在五年內完成10%綠...        產經
# ...

# %% [markdown]
# ### AND

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date >= '2021-01-01' AND  date <= '2021-07-01' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                           title  \
# 0                    電動車商品 衝勁十足
# 1            航運人氣續強 長榮處置期間大漲52%
# 2     【重磅快評】讚蔡英文辛苦籲珍惜疫苗 蘇揆是在哈囉嗎
# 3                  台積電神救援 電動車加速
# 4        魏哲家獲選亞洲半導體最佳CEO 談台積電創新
# ...                         ...
# 6168               企業綠能達標 要看二因素
# 6169       面板雙虎可望轉虧為盈 有機會恢復年度調薪
# 6170         中芯公布最新人事 董事名單仍有梁孟松
# 6171             跟進台積 世界先進加薪10%
# 6172    中芯國際公布最新董事名單 梁孟松仍任聯合CEO
#
#                                               paragraph cateTitle        date  \
# 0     美國總統拜登與兩黨參議員達成框架協議未來將花費150億美元用於建設電動車充電站，以及購買電動...        基金  2021-07-01
# 1     航運族群凝聚人氣，資金占大盤達逾38%，萬海成交值達1018.94億元，居上市之冠。長榮上演...        股市  2021-07-01
# 2     最近一名高雄的餐廳老闆受訪時提到，自己的餐廳受到疫情影響已經營不下去，說到激動處，他當著鏡頭...        評論  2021-07-01
# 3     第二季以來，市場聚焦「航海王」及「鋼鐵人」，熱絡行情吸引許多投資人不斷湧入，航海融資比率己高...        股市  2021-07-01
# 4     台積電總裁魏哲家近日獲選Institutional Investor Magazine的亞洲...        產經  2021-07-01
# ...                                                 ...       ...         ...
# ...

# %% [markdown]
# ### OR

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date <= '2021-01-01' OR  date >= '2021-07-01' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                           title  \
# 0         宣講公投案 賴副總統：三接攸關北部穩定供電
# 1     反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2             電子股資金撤出 法人：台股上攻缺量
# 3        外資小幅買超6.81億元 航空雙雄包辦前2名
# 4     林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                         ...
# 8158               曹興誠 強硬聲明展現擔當
# 8159              曹興誠,衝勁十足 能賺敢賺
# 8160            華碩董座施崇棠 捐台大5.4億
# 8161                 郭台銘送妻最後一程…
# 8162                在漫畫沃土 創動畫新潮
#
#                                               paragraph cateTitle        date  \
# 0     副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞  2021-11-24
# 1     反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞  2021-11-24
# 2     台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市  2021-11-24
# 3     台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市  2021-11-24
# 4     第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞  2021-11-24
# ...                                                 ...       ...         ...
# ...

# %% [markdown]
# ### BETWEEN

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date BETWEEN '2021-01-01' AND '2021-07-01' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                           title  \
# 0                    電動車商品 衝勁十足
# 1            航運人氣續強 長榮處置期間大漲52%
# 2     【重磅快評】讚蔡英文辛苦籲珍惜疫苗 蘇揆是在哈囉嗎
# 3                  台積電神救援 電動車加速
# 4        魏哲家獲選亞洲半導體最佳CEO 談台積電創新
# ...                         ...
# 6168               企業綠能達標 要看二因素
# 6169       面板雙虎可望轉虧為盈 有機會恢復年度調薪
# 6170         中芯公布最新人事 董事名單仍有梁孟松
# 6171             跟進台積 世界先進加薪10%
# 6172    中芯國際公布最新董事名單 梁孟松仍任聯合CEO
#
#                                               paragraph cateTitle        date  \
# 0     美國總統拜登與兩黨參議員達成框架協議未來將花費150億美元用於建設電動車充電站，以及購買電動...        基金  2021-07-01
# 1     航運族群凝聚人氣，資金占大盤達逾38%，萬海成交值達1018.94億元，居上市之冠。長榮上演...        股市  2021-07-01
# 2     最近一名高雄的餐廳老闆受訪時提到，自己的餐廳受到疫情影響已經營不下去，說到激動處，他當著鏡頭...        評論  2021-07-01
# 3     第二季以來，市場聚焦「航海王」及「鋼鐵人」，熱絡行情吸引許多投資人不斷湧入，航海融資比率己高...        股市  2021-07-01
# 4     台積電總裁魏哲家近日獲選Institutional Investor Magazine的亞洲...        產經  2021-07-01
# ...                                                 ...       ...         ...
# ...

# %% [markdown]
# ### IN

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE catetitle IN ('產經', '股市', '基金') 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                           title  \
# 0             電子股資金撤出 法人：台股上攻缺量
# 1        外資小幅買超6.81億元 航空雙雄包辦前2名
# 2      出口商拋匯支撐 新台幣升1.6分收27.793元
# 3      台積電首設廠務學院設在中科 已培育逾500位新人
# 4      聯電、南茂等六家半導體及材材料 挺光洋科經營團隊
# ...                         ...
# 8196            台股波動加大，留意先上後下走勢
# 8197           台股首季財報公佈前 大盤狹幅整理
# 8198           熱錢來襲！南韓、印尼外匯存底飆高
# 8199  基金facebook／鐘國忠投資三心法 搶賺龍年財
# 8200  基金facebook／陸行之 努力+努力 唯一心法
#
#                                               paragraph cateTitle        date  \
# 0     台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市  2021-11-24
# 1     台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市  2021-11-24
# 2     台股走跌，不過匯市部分外資偏向匯入，加上出口商月底有拋匯需求，新台幣兌美元今天收盤收27.7...        產經  2021-11-24
# 3     台積電（2330）今日對外說明，首設廠務學院在中科，同時該廠務學院今年已來已陸續培育逾500...        產經  2021-11-24
# 4     繼台積電力挺光洋科經團隊後，包括聯電、南茂、穩懋、晶技、錸寶、日揚科技等六家半導體及材料廠，...        產經  2021-11-24
# ...                                                 ...       ...         ...
# ...

# %% [markdown]
# ### NOT IN

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE catetitle NOT IN ('產經', '股市', '基金') 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# 3     擬徵「囤房稅」 不動產業界分析：高雄首購族居多不影響
# 4     擬徵「囤房稅」 不動產業界分析：高雄首購族居多不影響
# ...                          ...
# 6057                曹興誠 強硬聲明展現擔當
# 6058               曹興誠,衝勁十足 能賺敢賺
# 6059             華碩董座施崇棠 捐台大5.4億
# 6060                  郭台銘送妻最後一程…
# 6061                 在漫畫沃土 創動畫新潮
#
#                                               paragraph cateTitle        date  \
# 0     副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞  2021-11-24
# 1     反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞  2021-11-24
# 2     第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞  2021-11-24
# 3     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...       房地產  2021-11-24
# 4     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...        地方  2021-11-24
# ...                                                 ...       ...         ...
# ...

# %% [markdown]
# ### LIKE
# - start with '台積電'

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE paragraph LIKE '台積電%' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                                title  \
# 0           台積電首設廠務學院設在中科 已培育逾500位新人
# 1         擬徵「囤房稅」 不動產業界分析：高雄首購族居多不影響
# 2         擬徵「囤房稅」 不動產業界分析：高雄首購族居多不影響
# 3               台積電將設廠 日本經產大臣赴熊本現地視察
# 4     台積電ADR跌2.7%追隨費半下挫 較台北股票溢價10.2%
# ...                              ...
# 1565             張忠謀明年6月交棒劉德音 魏哲家任總裁
# 1566            張忠謀宣布明年六月退休 劉德音接任董事長
# 1567              張忠謀跌倒輕傷 醫師傳授老人防跌妙招
# 1568                   張忠謀養生招數 醫師也說讚
# 1569                張忠謀：台灣關鍵優先 對世界開放
#
#                                               paragraph cateTitle        date  \
# 0     台積電（2330）今日對外說明，首設廠務學院在中科，同時該廠務學院今年已來已陸續培育逾500...        產經  2021-11-24
# 1     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...       房地產  2021-11-24
# 2     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...        地方  2021-11-24
# 3     台積電已拍板赴日設晶圓製造廠，日本經濟產業大臣萩生田光一今天前往設廠預定地熊本縣，除視察台積...        全球  2021-11-24
# 4     台積電ADR周二（23日）跌2.72%，收報121.36美元，較台北交易股票溢價10.19%...        全球  2021-11-24
# ...

# %% [markdown]
# ### GROUP BY

# %%
query = '''
SELECT TIME, COUNT(*) AS cnt
FROM TSMC_NEWS 
WHERE paragraph LIKE '台積電%' 
GROUP BY date
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#          time  cnt
# 0    00:00:00    1
# 1    18:07:02    1
# 2    00:57:05    1
# 3    23:31:09   44
# 4    23:31:04    9
# ..        ...  ...
# 337  16:42:30    7
# 338  18:44:44    1
# 339  15:21:14    1
# 340  16:36:00    3
# 341  18:07:10    7
#
# [342 rows x 2 columns]

# %% [markdown]
# ### HAVING

# %%
query = '''
SELECT date, COUNT(*) AS cnt
FROM TSMC_NEWS 
WHERE paragraph LIKE '台積電%' 
GROUP BY date
HAVING CNT >=20
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#          date  cnt
# 0  2017-10-02   44
# 1  2021-04-15   27
# 2  2021-07-12   41
# 3  2021-07-15   21
# 4  2021-07-16   23
# 5  2021-11-10   44
# 6  2021-11-11   25

# %% [markdown]
# ### DISTINCT

# %%
query = '''
SELECT DISTINCT date
FROM TSMC_NEWS 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#            date
# 0    2021-11-24
# 1    2021-11-23
# 2    2021-11-22
# 3    2021-11-21
# 4    2021-11-20
# ..          ...
# 935  2007-03-15
# 936  2006-06-29
# 937  2006-06-18
# 938  2006-06-15
# 939  2005-06-14
#
# [940 rows x 1 columns]

# %% [markdown]
# ### SUM

# %%
query = '''
SELECT SUM(CNT)
FROM (
    SELECT date, COUNT(*) AS cnt
    FROM TSMC_NEWS 
    GROUP BY date
    ) A
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#    SUM(CNT)
# 0     14263

# %% [markdown]
# ### AVG

# %%
query = '''
SELECT AVG(CNT)
FROM (
    SELECT date, COUNT(*) AS cnt
    FROM TSMC_NEWS 
    GROUP BY date
    ) A
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#     AVG(CNT)
# 0  15.173404

# %% [markdown]
# ### UNION

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date = '2020-11-01' 

UNION

SELECT *
FROM TSMC_NEWS 
WHERE date = '2020-11-01' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                    title                                          paragraph  \
# 0     台積電青年學生文學獎 白先勇頒獎傳承  由聯合報副刊與台積電文教基金會共同主辦「台積電青年學生文學獎」昨舉行頒獎典禮，請來首屆評審、...
# 1  資金大戶回台低利推升熱潮 台灣房市量增價揚  資金狂潮簇擁下，房市急速升溫，「打房」與「炒房」已成網友討論度最高的關鍵字；雖然業者堅持房市...
#
#   cateTitle        date      time  \
# 0        閱讀  2020-11-01  01:57:16
# 1       房地產  2020-11-01  12:36:04
#
#                                                  url
# 0  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 1  https://pgw.udn.com.tw/gw/photo.php?u=https://...

# %% [markdown]
# ### UNION ALL

# %%
query = '''
SELECT *
FROM TSMC_NEWS 
WHERE date = '2020-11-01' 

UNION ALL

SELECT *
FROM TSMC_NEWS 
WHERE date = '2020-11-01' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                    title                                          paragraph  \
# 0  資金大戶回台低利推升熱潮 台灣房市量增價揚  資金狂潮簇擁下，房市急速升溫，「打房」與「炒房」已成網友討論度最高的關鍵字；雖然業者堅持房市...
# 1     台積電青年學生文學獎 白先勇頒獎傳承  由聯合報副刊與台積電文教基金會共同主辦「台積電青年學生文學獎」昨舉行頒獎典禮，請來首屆評審、...
# 2  資金大戶回台低利推升熱潮 台灣房市量增價揚  資金狂潮簇擁下，房市急速升溫，「打房」與「炒房」已成網友討論度最高的關鍵字；雖然業者堅持房市...
# 3     台積電青年學生文學獎 白先勇頒獎傳承  由聯合報副刊與台積電文教基金會共同主辦「台積電青年學生文學獎」昨舉行頒獎典禮，請來首屆評審、...
#
#   cateTitle        date      time  \
# 0       房地產  2020-11-01  12:36:04
# 1        閱讀  2020-11-01  01:57:16
# 2       房地產  2020-11-01  12:36:04
# 3        閱讀  2020-11-01  01:57:16
#
#                                                  url
# 0  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 1  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 2  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 3  https://pgw.udn.com.tw/gw/photo.php?u=https://...

# %% [markdown]
# ### CAST

# %%
# STRING TO INT
query = '''
SELECT CAST('1   ' AS DEC(4,0))
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#    CAST('1   ' AS DEC(4,0))
# 0                         1

# %%
# INT TO STRING
query = '''
SELECT CAST(1 AS VARCHAR(4))
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#   CAST(1 AS VARCHAR(4))
# 0                     1

# %%
# STRING TO TIME
query = '''
SELECT CAST ('20191201' as date format 'yyyymmdd') as yyyymmdd
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#    yyyymmdd
# 0  20191201

# %%
# # TO datetime
# query = '''
# SELECT cast('2021-01-01'|| ' ' || '00:00:00' as TIMESTAMP(0) FORMAT 'YYYY-MM-DD HH:MI:SS') as DATETIME
# '''
# df = pd.read_sql(sql = query, con=conn)
# df

# %%
# SELECT CAST ('20191201' as date format 'yyyymmdd') as yyyymmdd -- 轉為日期格式
# 		, add_months(yyyymmdd, 1) as yyyymmdd2 -- 加1個月
# 		, extract(year from yyyymmdd2) -- 萃取年的資訊
# 		, extract(month from yyyymmdd2) -- 萃取月的資訊
# 		, extract(day from yyyymmdd2) -- 萃取日的資訊

# %%
# SELECT (MAX_TIME - MIN_TIME) HOUR(4) TO SECOND AS DIFF_SEC AS DIFF_SEC -- 計算兩個時間差了幾個小時、分鐘與秒
# 		, EXTRACT(HOUR FROM DIFF_SEC) * 3600 + EXTRACT(MINUTE FROM DIFF_SEC) * 60 + EXTRACT(SECOND FROM DIFF_SEC) AS USAGE_TIME

# %% [markdown]
# ### LPAD/RPAD

# %%
# SELECT LPAD('12345', 8, '0')

# %% [markdown]
# ### CASE WHEN

# %%
query = '''
SELECT TITLE
		, DATE
        , CASE WHEN DATE >= '2021-01-01' THEN '2021'
         		WHEN DATE >= '2020-01-01' THEN '2020'
         		WHEN DATE >= '2019-01-01' THEN '2019'
        		ELSE '2018-' END AS year
FROM TSMC_NEWS 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title        date   year
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電  2021-11-24   2021
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法  2021-11-24   2021
# 2              電子股資金撤出 法人：台股上攻缺量  2021-11-24   2021
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名  2021-11-24   2021
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？  2021-11-24   2021
# ...                          ...         ...    ...
# 14258               曹興誠 強硬聲明展現擔當  2006-06-29  2018-
# 14259              曹興誠,衝勁十足 能賺敢賺  2006-06-29  2018-
# 14260            華碩董座施崇棠 捐台大5.4億  2006-06-18  2018-
# 14261                 郭台銘送妻最後一程…  2006-06-15  2018-
# 14262                在漫畫沃土 創動畫新潮  2005-06-14  2018-
#
# [14263 rows x 3 columns]

# %% [markdown]
# ### QUANTILE

# %%
# query = '''
# SELECT DATE
#     , COUNT(*) AS CNT
#     , QUANTILE(100, CNT) AS QUAN_CNT
# FROM TSMC_NEWS 
# GROUP BY DATE
# '''
# df = pd.read_sql(sql = query, con=conn)
# df

# %% [markdown]
# ### JOIN
# - INNER
# - LEFT

# %%
query = '''
SELECT CATETITLE, COUNT(*) AS CNT
FROM TSMC_NEWS
GROUP BY CATETITLE
HAVING CNT >= 500
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#   cateTitle   CNT
# 0        全球  1037
# 1        產經  3594
# 2        股市  4377
# 3        要聞  1150
# 4        雜誌  1331

# %%
query = '''
SELECT *
FROM TSMC_NEWS AS A
INNER JOIN (
    SELECT CATETITLE, COUNT(*) AS CNT
    FROM TSMC_NEWS
    GROUP BY CATETITLE
    HAVING CNT >= 500
    ) B
ON A.CATETITLE=B.CATETITLE
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                            title  \
# 0          宣講公投案 賴副總統：三接攸關北部穩定供電
# 1      反萊豬無法加入CPTPP？林麗蟬：綠營慣用操作手法
# 2              電子股資金撤出 法人：台股上攻缺量
# 3         外資小幅買超6.81億元 航空雙雄包辦前2名
# 4      林麗蟬嗆王美花：台灣護國神山什麼時候變成「神豬」？
# ...                          ...
# 11484         張忠謀宣布退休 外資：不捨！但非利空
# 11485       張忠謀無預警宣布退休 劉德音繼任新董事長
# 11486     這不是張忠謀首次宣布退休 竹科金融海嘯時回鍋
# 11487        張忠謀明年6月交棒劉德音 魏哲家任總裁
# 11488       張忠謀宣布明年六月退休 劉德音接任董事長
#
#                                                paragraph cateTitle  \
# 0      副總統賴清德今天晚上表示，4項公投案牽涉台灣的能源、經濟、環境、民主發展，也攸關台灣的國際貿...        要聞
# 1      反萊豬公投案正方代表林麗蟬今天說，是哪個CPTPP成員國要求台灣必須開放萊豬才能加入，把開放...        要聞
# 2      台股今天開高走低，台積電失守月線，指數終場跌23.6點，收17642.52點。法人分析，台股...        股市
# 3      台股今天收在17642.52點，下跌23.6點，成交值新台幣2918.67億元。外資買超6....        股市
# 4      第三場「反萊豬」電視公投說明會今晚登場，對於經濟部長王美花指反萊豬進口會讓台灣變成國際孤兒，...        要聞
# ...                                                  ...       ...
# 11484  台積電盤後發布重大訊息，董事長張忠謀宣布明年6月退休。歐系外資分析師說，張忠謀退休是遲早發生...        產經
# ...

# %% [markdown]
# ### REPLACE

# %%
query = '''
SELECT PARAGRAPH, REPLACE(PARAGRAPH, '台積電', '台GG')
FROM TSMC_NEWS
WHERE paragraph LIKE '台積電%' 
'''
df = pd.read_sql(sql = query, con=conn)
df
# Out:
#                                               paragraph  \
# 0     台積電（2330）今日對外說明，首設廠務學院在中科，同時該廠務學院今年已來已陸續培育逾500...
# 1     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...
# 2     台積電投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...
# 3     台積電已拍板赴日設晶圓製造廠，日本經濟產業大臣萩生田光一今天前往設廠預定地熊本縣，除視察台積...
# 4     台積電ADR周二（23日）跌2.72%，收報121.36美元，較台北交易股票溢價10.19%...
# ...                                                 ...
# 1565  台積電剛剛公告交棒計畫，董事長張忠謀宣布，他將在此屆董事任滿，2018年6月上旬股東大會後退...
# 1566  台積電董事長張忠謀董事長今天宣布：「本人將在此屆董事任滿，2018年6月上旬股東大會後退休。...
# 1567  台積電董事長張忠謀驚傳在夏威夷住家泳池畔跌倒，還好經證實後，只有擦傷無大礙。醫師表示，老人跌...
# 1568  台積電董事長張忠謀年逾80，但目光有神、思考犀利，而讓他能持續率領企業壯盛的背後原因，就是貫...
# 1569  台積電董事長張忠謀今日下午表示，台灣關鍵兩年的優先選擇，就是要積極的對世界開放。張忠謀贊同上...
#
#                        REPLACE(PARAGRAPH, '台積電', '台GG')
# 0     台GG（2330）今日對外說明，首設廠務學院在中科，同時該廠務學院今年已來已陸續培育逾500...
# 1     台GG投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...
# 2     台GG投資產生房價上漲效應，高雄市長陳其邁宣布推動「囤房稅」，今年12月底前擬訂「高雄市房屋...
# 3     台GG已拍板赴日設晶圓製造廠，日本經濟產業大臣萩生田光一今天前往設廠預定地熊本縣，除視察台G...
# ...

# %% [markdown]
# ### DECLARE VARIABLES

# %%
# WITH VARIABLES AS
# (
# 	SELECT '2021-05-01' AS MINDATE,
#     	   '2021-05-31' AS MAXDATE
# )
# SELECT *
# FROM TSMC_NEWS, VARIABLES
# WHERE DATE BETWEEN VARIABLES.MINDATE AND VARIABLES.MINDATE

# %% [markdown]
# ### DATE

# %%
# query = '''
# SELECT DATE
# '''
# df = pd.read_sql(sql = query, con=conn)
# df

# %%
# query = '''
# SELECT EXTRACT (YEAR FROM DATE)
# '''
# df = pd.read_sql(sql = query, con=conn)
# df

# %%
# query = '''
# SELECT EXTRACT (MONTH FROM DATE)
# '''
# df = pd.read_sql(sql = query, con=conn)
# df

# %%
# SELECT EXTRACT (DAY FROM DATE)
# SELECT EXTRACT (HOUR FROM '12:34:56')
# SELECT EXTRACT (MINUTE FROM '12:34:56')
# SELECT EXTRACT (SECOND FROM '12:34:56')

# %% [markdown]
# ### STRTOK

# %% [markdown]
# ### QUALIFY
