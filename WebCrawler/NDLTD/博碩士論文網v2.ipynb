# %% [markdown]
# 檢索策略："博士".ty and ("社會服務學門" or "社會及行為科學學門").sglv1；檢索結果共 4205 筆資料

# %%
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import pandas as pd

# %% [markdown]
# # 收集論文清單

# %%
df = []
r1 = 1
while r1 <= 4207:
    columns = []
    values = []
    try:
        res2 = rs.get('https://ndltd.ncl.edu.tw/cgi-bin/gs32/gsweb.cgi/ccd={}/record?r1={}&h1=1'.format(cookie, r1))
        soup = BeautifulSoup(res2.text)
        for i in soup.find('table', {'id':'format0_disparea'}).findAll('tr'):
            if 'std1' in str(i):
                print(i.find('th',{'class':'std1'}).text)
                columns.append(i.find('th',{'class':'std1'}).text)
                print(i.find('td',{'class':'std2'}).text)
                values.append(i.find('td',{'class':'std2'}).text)
        
        # 永久網址
        columns.append('永久網址')
        try:
            permanent = soup.find('input',{'id':'fe_text1'})['value']
        except:
            permanent = ''
        values.append(permanent)
        print('永久網址：', permanent)
        
        # 摘要
        columns.append('摘要')
        try:
            abst = soup.find('td',{'class':'stdncl2'}).text
        except:
            abst = ''
        values.append(abst)
#         print('摘要：', abst)
        
        # 引用
        columns.append('引用')
        try:
            Quote = str(soup.find('div',{'style':'padding:10px;text-align:left;'}))
        except:
            Quote = ''
        values.append(Quote)
#         print('引用：', Quote)
        
        ndf = pd.DataFrame(data=values, index=columns).T
        
        df.append(ndf)
        r1 += 1  
        print('='*88)
    except:
        # Cookie 失效時自動重啟 Selenium 取得新的 Cookie，並更新參數
        print('Get New Cookie')
        driver = webdriver.Chrome()
        driver.get('https://ndltd.ncl.edu.tw/')
        sleep(2)
        driver.find_element_by_xpath('//a[@title="指令查詢"]').click()
        sleep(2)
        driver.find_element_by_id('ysearchinput0').send_keys('"博士".ty and ("社會服務學門" or "社會及行為科學學門").sglv1')
        sleep(0.5)
        driver.find_element_by_id('gs32search').click()
        sleep(2)
        cookie = re.findall(r'ccd=(.*?)/', driver.current_url)[0]
        driver.close()
        headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
                 'Cookie': 'ccd={}'.format(cookie)}
        
        payload = {'qs0': '"博士".ty and ("社會服務學門" or "社會及行為科學學門").sglv1',
                   'qf0': '_hist_',
                   'gs32search.x': '27',
                   'gs32search.y': '9',
                   'displayonerecdisable': '1',
                   'dbcode': 'nclcdr',
                   'action':'',
                   'op':'',
                   'h':'',
                   'histlist':'',
                   'opt': 'm',
                   '_status_': 'search__v2'}
        
        rs = requests.session()
        res = rs.post('https://ndltd.ncl.edu.tw/cgi-bin/gs32/gsweb.cgi/ccd={}/search'.format(cookie),data=payload, headers=headers)
# Out:
# Get New Cookie
# Get New Cookie
# Get New Cookie
# Get New Cookie
# Get New Cookie
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 張鐸瀚
# 研究生(外文):
# To-Han Chang
# 論文名稱:
# 價格調整限制下非線性定價分析
# 論文名稱(外文):
# Nonlinear Pricing under Price Adjustment Constraints
# 指導教授:
# 張明宗
# 指導教授(外文):
# Ming Chung Chang
# 學位類別:
# 博士
# 校院名稱:
# 國立中央大學
# 系所名稱:
# 產業經濟研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 99
# 中文關鍵詞:
# 非線性定價、價格上限管制法、拉氏收益限制式、巴氏收益限制式、收益分離限制式
# 外文關鍵詞:
# nonlinear pricing、price-cap regulation、Laspeyres revenue constraint、Paasche revenue constraint、separate revenue constraints
# 相關次數:
#
#
# 被引用:4點閱:515評分:下載:135書目收藏:4
#
#
# 永久網址： https://hdl.handle.net/11296/pp6762
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 張貴傑
# 研究生(外文):
# Chang, Kuei-chieh
# 論文名稱:
# 變，生命歷程的實踐與建構：一個生命體自我成長經驗的探究與反思
# 論文名稱(外文):
# Change-The construct and praxis of life:The study of an individual''''s self-growth experiences
# 指導教授:
# 蕭文
# 學位類別:
# 博士
# 校院名稱:
# 國立彰化師範大學
# 系所名稱:
# 輔導與諮商系
# 學門:
# 社會及行為科學學門
# 學類:
# 心理學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 180
# 中文關鍵詞:
# 詮釋學、改變、自我成長經驗
# 外文關鍵詞:
# Hermeneutics、change、self-growth experiences
# 相關次數:
#
#
# 被引用:33點閱:2738評分:下載:0書目收藏:20
#
#
# 永久網址： https://hdl.handle.net/11296/z2b5d6
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 吳嘉瑜
# 研究生(外文):
# Juyu,wu
# 論文名稱:
# 代間矛盾經驗之分析：成年子女婚後與父母之關係研究
# 論文名稱(外文):
# Intergenerational Ambivalent Experiences：The Relationships Between Adult Married Offspring and Parents
# 指導教授:
# 趙淑珠
# 指導教授(外文):
# Shu-chu,Gu
# 學位類別:
# 博士
# 校院名稱:
# 國立彰化師範大學
# 系所名稱:
# 輔導與諮商系
# 學門:
# 社會及行為科學學門
# 學類:
# 心理學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 271
# 中文關鍵詞:
# 代間矛盾經驗、代間關係、老年父母、成年子女、配對研究
# 外文關鍵詞:
# Intergenerational Ambivalent Experiences、Intergenerational relationships、Aging Parents、Adult Children、Paired Research
# 相關次數:
#
#
# 被引用:90點閱:2345評分:下載:0書目收藏:10
#
#
# 永久網址： https://hdl.handle.net/11296/tp48uq
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 蔡素妙
# 研究生(外文):
# Tsai Su-Miao
# 論文名稱:
# 九二一受創家庭復原力之變化分析研究
# 論文名稱(外文):
# A n Analytical Study on the Resilience Process of the Families Traumatized by 921 Earthquake
# 指導教授:
# 蕭文
# 指導教授(外文):
# Hsiao  Wein
# 學位類別:
# 博士
# 校院名稱:
# 國立彰化師範大學
# 系所名稱:
# 輔導與諮商系
# 學門:
# 社會及行為科學學門
# 學類:
# 心理學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 230
# 中文關鍵詞:
# 921地震、受創家庭、復原力
# 外文關鍵詞:
# 921 earthquake、traumatized family、resilience
# 相關次數:
#
#
# 被引用:95點閱:2559評分:下載:767書目收藏:20
#
#
# 永久網址： https://hdl.handle.net/11296/uvtcc8
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 張立宇
# 研究生(外文):
# Chang Li-Yu
# 論文名稱:
# 民意代表宣誓之研究-以第三屆立法委員宣誓爭議為例
# 論文名稱(外文):
# The studies on Legislators'' Oath-The Case Stusy of Oath of The Third session of Legislators''
# 指導教授:
# 楊日旭
# 指導教授(外文):
# Dr.Richard H.Yang
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 中山學術研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2001
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 360
# 中文關鍵詞:
# 憲政主義、宣誓、立委
# 外文關鍵詞:
# oath、thconstitutionalism、Legislators
# 相關次數:
#
#
# 被引用:1點閱:239評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/5q5z43
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 鄭劍豪
# 論文名稱:
# 馬克思社會發展理論之研究
# 論文名稱(外文):
# Karl Marx''s Social Development theory
# 指導教授:
# 楊世雄
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 200
# 中文關鍵詞:
# 生產力、上層建築、階級意識、社會發展、意識形態、理性重建
# 相關次數:
#
#
# 被引用:8點閱:1256評分:下載:530書目收藏:6
#
#
# 永久網址： https://hdl.handle.net/11296/898p6a
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 賴振生
# 論文名稱:
# 後冷戰時期東北亞區域安全體制建立之研究
# 指導教授:
# 蔡政文
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 283
# 中文關鍵詞:
# 後冷戰時期、東北亞、區域安全
# 相關次數:
#
#
# 被引用:6點閱:596評分:下載:140書目收藏:2
#
#
# 永久網址： https://hdl.handle.net/11296/z7h988
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 林仲修
# 論文名稱:
# 台灣政治轉型中國家蛻變之內環境因素分析
# 指導教授:
# 紀俊臣
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 中文關鍵詞:
# 國家、政治轉型、意識型態、憲政體制、政黨體系、威權統合體制、分裂性政府、政黨輪替
# 相關次數:
#
#
# 被引用:38點閱:1275評分:下載:376書目收藏:7
#
#
# 永久網址： https://hdl.handle.net/11296/5385kt
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 齊光裕
# 研究生(外文):
# KUNG-YUE CHI
# 論文名稱:
# 我國違憲審查中「政治問題」之研究
# 論文名稱(外文):
# A Study of the Political Question of The Judicial Review for The ROC
# 指導教授:
# 李炳南
# 指導教授(外文):
# BIING-NAN LEE
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 474
# 中文關鍵詞:
# 大法官會議、司法違憲審查、政治問題、憲法優位、權力分立、多數決原則、布瑞南準則、司法自制
# 外文關鍵詞:
# Council of Grand Justices、Judicial Review、political question、doctrine of constitutional supremacy、doctrine of seperation of power、doctrine of majority decision、Brenan Test、judicial self－restraint
# 相關次數:
#
#
# 被引用:7點閱:675評分:下載:185書目收藏:3
#
#
# 永久網址： https://hdl.handle.net/11296/6924fq
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 呂世昌
# 研究生(外文):
# Lu Shih-Chang
# 論文名稱:
# 單一選區兩票制政治效果之研究
# 指導教授:
# 吳文程
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 392
# 中文關鍵詞:
# 選舉制度、政黨體系、政治效果、杜弗傑定律、杜弗傑假設、兩票制、單一選區─比例代表制混合制、混合制、個人化比例代表制、向心競爭、離心競爭、雙重候選、分裂投票、中華民國、德國、日本
# 外文關鍵詞:
# electoral systems、party systems、political consequence、Duverger’s Law、Duverger’s Hypothesis、two votes system、mixed-member proportional、MMP、Hybrid systems、personalized proportional representation、centripetal competition、centrifugal competition、dual candidacy、split-ticket voting、R.O.C.、German、Japan.
# 相關次數:
#
#
# 被引用:53點閱:1120評分:下載:262書目收藏:5
#
#
# 永久網址： https://hdl.handle.net/11296/b93fj3
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 梁國常
# 研究生(外文):
# Kuo-chang Liang
# 論文名稱:
# 遊客對風景遊憩區認知意象之研究--以陽明山國家公園為例
# 論文名稱(外文):
# A Study of Visitors'' Cognitive Image of the Scenic Recreation Area -an example of Yangmingshan National Park-
# 指導教授:
# 陳國彥、嚴勝雄
# 指導教授(外文):
# Kuo-yen Chen、Sen-shun Yen
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣師範大學
# 系所名稱:
# 地理研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 地理學類
# 論文出版年:
# 2002
# 畢業學年度:
# 90
# 語文別:
# 中文
# 論文頁數:
# 208
# 中文關鍵詞:
# 認知、意象元素、認知圖、陽明山國家公園
# 外文關鍵詞:
# cognition、image elements、cognitive map、Yangmingshan Natiional Park
# 相關次數:
#
#
# 被引用:83點閱:1254評分:下載:0書目收藏:17
#
#
# 永久網址： https://hdl.handle.net/11296/5r4xm2
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 鄭怡世
# 研究生(外文):
# Yi-Shih Cheng
# 論文名稱:
# 台灣社會工作發展的歷史分析：1949-1982
# 論文名稱(外文):
# A Historical Study of Social Work Development in Taiwan 1949-1982
# 指導教授:
# 張英陣
# 指導教授(外文):
# Ying-Chen Chang
# 學位類別:
# 博士
# 校院名稱:
# 國立暨南國際大學
# 系所名稱:
# 社會政策與社會工作學系
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 320
# 中文關鍵詞:
# 台灣、社會工作歷史、社會工作發展、國家與社會工作、專業
# 外文關鍵詞:
# Taiwan、state、social work development、social work history、social work profession
# 相關次數:
#
#
# 被引用:59點閱:6068評分:下載:868書目收藏:8
#
#
# 永久網址： https://hdl.handle.net/11296/pr6656
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 李承禹
# 研究生(外文):
# Cheng-Yu Lee
# 論文名稱:
# 後冷戰時期美軍低強度衝突行動之研究
# 論文名稱(外文):
# The Study of U.S. Army Low Intensity Conflict Operations in the Post Cold War Period
# 指導教授:
# 洪陸訓
# 指導教授(外文):
# Lu-Hsun Hung
# 學位類別:
# 博士
# 校院名稱:
# 政治作戰學校
# 系所名稱:
# 政治研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 270
# 中文關鍵詞:
# 低強度衝突、國家利益、不對稱威脅、政治軍事
# 外文關鍵詞:
# low intensity conflict、national interest、asymmetric threats、politico-military
# 相關次數:
#
#
# 被引用:4點閱:788評分:下載:493書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/87p977
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃小玲
# 研究生(外文):
# Huang Hsiao-Ling
# 論文名稱:
# 納莉(2001)颱風之數值模擬研究
# 論文名稱(外文):
# A Modeling Study of Typhoon Nari (2001)
# 指導教授:
# 楊明仁
# 指導教授(外文):
# Yang Ming-Jen
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 地學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 地理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 146
# 中文關鍵詞:
#
# 納莉颱風
# 降水
#
# 外文關鍵詞:
# Typhoon Nari、precipitarion
# 相關次數:
#
#
# 被引用:2點閱:249評分:下載:110書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/dhnwc9
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 李源明
# 研究生(外文):
# Yuan-Ming Lee
# 論文名稱:
# 股價報酬(波動)與產出成長(波動)之間關係的探討
# 論文名稱(外文):
# The analysis of the relationship between stock returns (volatility) and economic growth (volatility)
# 指導教授:
# 黃柏農
# 學位類別:
# 博士
# 校院名稱:
# 國立中正大學
# 系所名稱:
# 國際經濟所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 230
# 中文關鍵詞:
# 波動、代理假說、費雪效果、當期景氣衰退指標、因果關係、股價報酬、經濟成長、門檻(向量)自我迴歸模型
# 外文關鍵詞:
# Fisher effect、the Proxy Hypothesis、Volatility、Current depth of recession (CDR)、Causality、Threshold (Vector) Autoregressive、Economic growth、Stock return
# 相關次數:
#
#
# 被引用:5點閱:1041評分:下載:341書目收藏:3
#
#
# 永久網址： https://hdl.handle.net/11296/gjvmf7
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 孫幸慈
# 研究生(外文):
# HSing-Tzu Sun
# 論文名稱:
# 身體受虐兒童團體遊戲治療歷程之分析研究
# 論文名稱(外文):
# The process research of the physical abused children in the group play therapy
# 指導教授:
# 黃正鵠
# 學位類別:
# 博士
# 校院名稱:
# 國立高雄師範大學
# 系所名稱:
# 輔導與諮商研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 心理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 313
# 中文關鍵詞:
# 團體遊戲治療、身體受虐兒童、團體歷程
# 外文關鍵詞:
# abused children、group play therapy
# 相關次數:
#
#
# 被引用:17點閱:1237評分:下載:0書目收藏:14
#
#
# 永久網址： https://hdl.handle.net/11296/ay38mn
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 劉邦富
# 研究生(外文):
# Pang-fu Liu
# 論文名稱:
# 台灣貧窮家庭兒童照顧政策落差研究
# 論文名稱(外文):
# Examining the Gaps in Child Care Policies for Poor Families in Taiwan
# 指導教授:
# 簡春安
# 指導教授(外文):
# Chun-an Chien
# 學位類別:
# 博士
# 校院名稱:
# 東海大學
# 系所名稱:
# 社會工作學系
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 208
# 中文關鍵詞:
# 兒童照顧、政策落差、府際關係、政策網絡
# 外文關鍵詞:
# child care、policy gap、intergovernmental relations、policy network
# 相關次數:
#
#
# 被引用:18點閱:3489評分:下載:856書目收藏:14
#
#
# 永久網址： https://hdl.handle.net/11296/f3fr6d
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 桂宏誠
# 研究生(外文):
# kuei, Hong-Chen
# 論文名稱:
# 議會制度在中國趨向式微的考察：憲政觀念與制度選擇的原意
# 論文名稱(外文):
# The Observation of Fading Parliamentarianism in China:The Original Intention of “Constitutionalism” and Institutional Choices
# 指導教授:
# 周陽山
# 指導教授(外文):
# Chou, Yung-Sen
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 中山學術研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 324
# 中文關鍵詞:
# 議院、國會、立憲政體、憲政、憲法、責任內閣制、議會內閣制、總統制、民權、共和、民主
# 外文關鍵詞:
# yi-yuan、parliament(Kuo-Huei)、constitutionalism、parliamentarism、presidential system、responsible-cabinet system、people’s rights、ming-quan、gon-ho、ming-chu
# 相關次數:
#
#
# 被引用:4點閱:550評分:下載:190書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/y8amvn
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 鄭如安
# 研究生(外文):
# cheng ju an
# 論文名稱:
# 身體受虐兒童親子互動遊戲諮商模式之建構
# 論文名稱(外文):
# The Construction of Counseling Model of Parent-Child Interaction Play for Physical Abused Child
# 指導教授:
# 廖鳳池
# 指導教授(外文):
# Liao Feng Tsu
# 學位類別:
# 博士
# 校院名稱:
# 國立高雄師範大學
# 系所名稱:
# 輔導與諮商研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 心理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 340
# 中文關鍵詞:
# 身體受虐兒童、任務分析、身體受虐兒童親子互動遊戲諮商模式
# 外文關鍵詞:
# physical abused child、task analysis、The Counseling Model of Parent-Child Interaction Play for Physical Abused Child
# 相關次數:
#
#
# 被引用:18點閱:862評分:下載:0書目收藏:16
#
#
# 永久網址： https://hdl.handle.net/11296/dgn9sn
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃秀香
# 研究生(外文):
# Hsiow Hsiang Hwang
# 論文名稱:
# 女性單親家庭就業培力與服務輸送機制之研究－以台北市為例
# 論文名稱(外文):
# The Efficacy of Employment Assistance and Service Delivery Matching for Single Parent Families Headed by Women －A Study in Taipei City
# 指導教授:
# 曾華源
# 指導教授(外文):
# Hua-Yuan Tzeng
# 學位類別:
# 博士
# 校院名稱:
# 東海大學
# 系所名稱:
# 社會工作學系
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 196
# 中文關鍵詞:
# 女性單親就業培力、就業服務輸送、失業與就業
# 外文關鍵詞:
# Single-Parent Females、Empower Employment、Occupational Service Delivery、Unemploymemt、Employment
# 相關次數:
#
#
# 被引用:13點閱:1959評分:下載:530書目收藏:18
#
#
# 永久網址： https://hdl.handle.net/11296/xfxcz9
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 郭仲凌
# 研究生(外文):
# Chung-ling Kuo
# 論文名稱:
# 觀光潛力區轉型變遷與發展策略-以台北縣龍門露營區為例
# 論文名稱(外文):
# Transformation and Development Strategies of Tourism Potential Area-A Case Study on Lungman Camping Park in Taipei County
# 指導教授:
# 曾國雄
# 指導教授(外文):
# Gwo-Hshiung Tzeng
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 地學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 地理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 133
# 中文關鍵詞:
# 觀光、觀光潛力區、地理資訊系統、DEA評估法、觀光地理資訊系統
# 外文關鍵詞:
# Tourism、Potential、DEA
# 相關次數:
#
#
# 被引用:7點閱:438評分:下載:0書目收藏:7
#
#
# 永久網址： https://hdl.handle.net/11296/4tkm9p
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 謝元入
# 研究生(外文):
# Hsiew,Ynan-Ju
# 論文名稱:
# 高雄地區工業化空間擴散及其影響之研究
# 論文名稱(外文):
# The spatial diffusion of industrialization and Its influence in Kaohsiung Area
# 指導教授:
# 薛益忠
# 指導教授(外文):
# Hsneh,Yi-Chung
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 地學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 地理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 157
# 中文關鍵詞:
# 傳布效應、出口導向工業化、防禦型對外直接投資、都市核心區、成長引擎、防禦型、製造業、價值性、成長率、階段
# 外文關鍵詞:
# Spread effect、export-oriented industrialization、defensive foreign direct investment、urban core、engine of growth、knowledge、issue
# 相關次數:
#
#
# 被引用:1點閱:555評分:下載:0書目收藏:12
#
#
# 永久網址： https://hdl.handle.net/11296/53ep9v
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 卓盈旻
# 研究生(外文):
# Cho Yin-Min
# 論文名稱:
# 亞洲夏季季風年際變化：熱帶海溫之影響
# 論文名稱(外文):
# The interannual variation of Asian summer monsoon:The influence of tropical SST
# 指導教授:
# 余嘉裕
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 地學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 地理學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 197
# 中文關鍵詞:
# 夏季季風  海氣交互作用
# 相關次數:
#
#
# 被引用:2點閱:157評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/kk2jvf
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 陳菁雯
# 研究生(外文):
# Chen, Ching-Wen
# 論文名稱:
# 官僚組織課責行為模式之研究：理論建構與實務驗證
# 論文名稱(外文):
# A Study on the Behavioral Pattern of Bureaucratic Accountability: Theory Formulation and Empirical Verification
# 指導教授:
# 江炳倫、江明修
# 指導教授(外文):
# Chiang, Pin-Lun、Chiang, Min-Hsiu
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 政治學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 260
# 中文關鍵詞:
# 官僚組織、課責、法律課責、層級課責、政治課責、專業課責、理性選擇
# 外文關鍵詞:
# bureaucracy、accountability、legal accountability、hierarchical accountability、political accountability、professional accountability、rational choice
# 相關次數:
#
#
# 被引用:11點閱:747評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/25snmf
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃淑芳
# 研究生(外文):
# Huang,Shu-Fang
# 論文名稱:
# 政黨的政治社會化與政治甄補功能之研究－－以中國國民黨革命實踐研究院為個案之分析
# 論文名稱(外文):
# Party Functions of Political Socialization and Recruitment－A Case-study on "Sun Yat-sen Institution on Policy Research and Development" in KMT
# 指導教授:
# 葛永光
# 指導教授(外文):
# Ger,Yeong-Kuang
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 中山學術研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 366
# 中文關鍵詞:
# 政黨、政治社會化、政治甄補、革命實踐研究院
# 外文關鍵詞:
# party、political socialization、political recruitment、Sun Yat-sen Institution on Policy Research and Development
# 相關次數:
#
#
# 被引用:5點閱:467評分:下載:0書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/z4z77s
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 林修正
# 論文名稱:
# 台灣土地稅累進稅VS比例稅比較研究
# 指導教授:
# 蔡吉源
# 學位類別:
# 博士
# 校院名稱:
# 國立政治大學
# 系所名稱:
# 中山人文社會科學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2005
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 216
# 中文關鍵詞:
# 土地稅、地價稅、土地增值稅、比例稅、累進稅、地價、地租曲線
# 外文關鍵詞:
# land tax、land value tax、Land value increment tax rate、Proportional tax、Progressive tax rate、land price、rent curve
# 相關次數:
#
#
# 被引用:1點閱:541評分:下載:0書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/7u3r9h
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 李文郎
# 研究生(外文):
# Lee,Wen-Lang
# 論文名稱:
# 修憲後我國監察制度與芬蘭國會監察使制度之比較分析
# 指導教授:
# 周陽山
# 指導教授(外文):
# Chou,Yang-Sun
# 學位類別:
# 博士
# 校院名稱:
# 國立政治大學
# 系所名稱:
# 中山人文社會科學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2005
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 387
# 中文關鍵詞:
# 監察權、監察使、監察院、國會、半總統制、芬蘭、權力分立、有限政府、第四權
# 外文關鍵詞:
# Control Power、Ombudsman、Control Yuan、Parliament、Semi-Presidentialism、Finland、Separation of Powers、Limited Government、The Fourth Branch of Power
# 相關次數:
#
#
# 被引用:16點閱:395評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/uacv4r
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 廖仲仁
# 研究生(外文):
# Liao，Chung-Jen
# 論文名稱:
# 住宅市場之價格搜尋行為-定錨效果、仲介服務與市場機制選擇之影響
# 論文名稱(外文):
# Housing Price Search Bebavior: The Effects of Anchoring, Brokerage Service, and Market Mechanism Choice
# 指導教授:
# 張金鶚
# 指導教授(外文):
# Chang，Chin-Oh
# 學位類別:
# 博士
# 校院名稱:
# 國立政治大學
# 系所名稱:
# 地政研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 公共行政學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 110
# 中文關鍵詞:
# 搜尋成本、分量迴歸、仲介服務、價格分散、市場機制、定錨效應
# 外文關鍵詞:
# search cost、quantile regression、brokerage service、price dispersion、market mechanism、anchoring effect
# 相關次數:
#
#
# 被引用:12點閱:410評分:下載:0書目收藏:7
#
#
# 永久網址： https://hdl.handle.net/11296/k454yf
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 陳碧珍
# 研究生(外文):
# Bi-Chen Chen
# 論文名稱:
# 群體共識判斷中社會影響網絡之研究--資訊整合理論之應用
# 論文名稱(外文):
# A Study on Social Influence Network in Consensus Group Judgment: Application of Information Integration Theory
# 指導教授:
# 汪明生
# 指導教授(外文):
# Ming-Shen Wang
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 公共事務管理研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 公共行政學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 204
# 中文關鍵詞:
# 群體決策、社會判斷理論、資訊整合理論、決策與判斷、認知衝突典範、社會權重、規範/資訊影響、認知/偏好回饋
# 外文關鍵詞:
# information integration theory (IIT)、social weight、social judgment theory (SJT)、cognitive conflict paradigm (CCP)、cognitive/preference feedback、decision-making and judgment、normative/ informational influence、group decision-making
# 相關次數:
#
#
# 被引用:19點閱:353評分:下載:0書目收藏:4
#
#
# 永久網址： https://hdl.handle.net/11296/9f22kg
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 劉瀚宇
# 研究生(外文):
# Han-yu Liu
# 論文名稱:
# 中華人民共和國人民代表大會選舉制度之研究
# 論文名稱(外文):
# The Electoral System of The People’s Congress of China
# 指導教授:
# 林文程
# 指導教授(外文):
# Wen-cheng Lin
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 大陸研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 區域研究學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 469
# 中文關鍵詞:
# 人民代表大會、選舉
# 外文關鍵詞:
# election、people''s congress
# 相關次數:
#
#
# 被引用:4點閱:523評分:下載:200書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/4bk2fk
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃宗誠
# 研究生(外文):
# Tsung-Cheng Huang
# 論文名稱:
# 兩岸大學MPA課程結構比較分析
# 論文名稱(外文):
# Structural Comparative Analysis of MPA Programs between Taiwan and Mainland Chinese Universities
# 指導教授:
# 汪銘生
# 指導教授(外文):
# Ming-shen Wang
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 公共事務管理研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 公共行政學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 439
# 中文關鍵詞:
# 數量化理論、公共管理、公共事務管理、教育體制、公共行政
# 外文關鍵詞:
# public management、education system、Hayashi’s quantification theory、public administration、public affairs management
# 相關次數:
#
#
# 被引用:13點閱:577評分:下載:141書目收藏:5
#
#
# 永久網址： https://hdl.handle.net/11296/26tyuk
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 虞伯樂
# 研究生(外文):
# Po-lo Yu
# 論文名稱:
# 全球化脈絡下高雄港埠民營化對工會重構影響之研究
# 論文名稱(外文):
# The Impact of Kaohsiung Port Privatization on Union Reconstruction under the Globalization
# 指導教授:
# 朱柔若
# 指導教授(外文):
# Jou-juo Chu
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 中山學術研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2006
# 畢業學年度:
# 94
# 語文別:
# 中文
# 論文頁數:
# 261
# 中文關鍵詞:
# 民營化、工會發展、去管制化、港埠改革、碼頭工會
# 外文關鍵詞:
# privatization、deregulation、port reform
# 相關次數:
#
#
# 被引用:0點閱:380評分:下載:0書目收藏:2
#
#
# 永久網址： https://hdl.handle.net/11296/594239
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 蔡淑鳳
# 研究生(外文):
# Shwu-feng Tsay
# 論文名稱:
# 老人照護機構多元環境品質管理之政策研究
# 論文名稱(外文):
# The Policy Research of Quality Management from Multiphasic Environmental Assessment Procedure in Elderly Care Facilities
# 指導教授:
# 吳濟華
# 學位類別:
# 博士
# 校院名稱:
# 國立中山大學
# 系所名稱:
# 公共事務管理研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 公共行政學類
# 論文出版年:
# 2007
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 282
# 中文關鍵詞:
# 多元環境評估量表、多元環境品質指標、老人照護機構、老人
# 外文關鍵詞:
# Multiphasic-Environmental Assessment Procedure (MEAP)、multiple environmental quality index、elderly care facilities、elderly
# 相關次數:
#
#
# 被引用:5點閱:1004評分:下載:0書目收藏:4
#
#
# 永久網址： https://hdl.handle.net/11296/4ws7yp
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 柯朝欽
# 研究生(外文):
# Chao-Chin Ko
# 論文名稱:
# 例外狀態的統治與救贖：論阿岡本的兩種例外狀態模式
# 論文名稱(外文):
# The Government and Salvation of the State of Exception: two mode of State of Exception of Giorgio Agamben
# 指導教授:
# 朱元鴻
# 指導教授(外文):
# Yuan-Horng Chu
# 學位類別:
# 博士
# 校院名稱:
# 東海大學
# 系所名稱:
# 社會學系
# 學門:
# 社會及行為科學學門
# 學類:
# 社會學類
# 論文出版年:
# 2006
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 147
# 中文關鍵詞:
# 阿岡本、傅柯、班雅明、史密特、生命政治、例外狀態、彌賽亞主義、赤裸生命、潛能性、主權
# 外文關鍵詞:
# Giorgio Agamben、bio-politics、Michel Foucault、Walter Benjamin、Carl Schmitt、state of exception、messanicism、bare-life、Sovereignty、potentiality、impotentiality
# 相關次數:
#
#
# 被引用:9點閱:5936評分:下載:2781書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/h73kdt
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 況正吉
# 研究生(外文):
# Kuang Chang-Chi
# 論文名稱:
# 中國大陸與俄羅斯政治經濟改革對於大型國有企業公司治理之影響：以比較俄國統一電力公司和中國華能集團公司為例
# 論文名稱(外文):
# The Influence of the Political and Economic Reform of China and Russia upon Corporate Governance of SOEs：A Comparative Researchof RAO “UES of Russia” and China Huaneng power company
# 指導教授:
# 周陽山
# 指導教授(外文):
# Zhou Yang-Shan
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 政治學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2006
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 321
# 中文關鍵詞:
# 震盪治療、漸進主義、公司治理、內部人控制、國有企業、電力公司、代理理論、交易費用理論、利益相關者理論
# 外文關鍵詞:
# shock therapy、gradualism、corporate goverance、insider control、state-owned enterprises、electric power company、agency theory、transaction-cost theory、stakeholder theory
# 相關次數:
#
#
# 被引用:3點閱:2278評分:下載:1736書目收藏:3
#
#
# 永久網址： https://hdl.handle.net/11296/3v7phx
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 陳信傑
# 研究生(外文):
# Chen, Hsin-Chieh
# 論文名稱:
# 台灣的國家定位：三種國家類型的探討
# 指導教授:
# 呂亞力
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 政治學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2006
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 365
# 中文關鍵詞:
# 新生國家類型、分離國家類型、分裂國家類型、認同、憲政、自決
# 相關次數:
#
#
# 被引用:6點閱:3179評分:下載:1777書目收藏:2
#
#
# 永久網址： https://hdl.handle.net/11296/jk2f7n
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 蔡佩真
# 研究生(外文):
# Tsai  Pei Jen
# 論文名稱:
# 台灣癌症喪親家庭關係之變化與探究
# 論文名稱(外文):
# How The relationship of Cancer Bereaved Family Shuffles in Taiwan's Research
# 指導教授:
# 楊瑩
# 指導教授(外文):
# Yung Ying
# 學位類別:
# 博士
# 校院名稱:
# 國立暨南國際大學
# 系所名稱:
# 社會政策與社會工作學系
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 論文出版年:
# 2006
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 251
# 中文關鍵詞:
# 喪親服務、喪親家庭、家庭關係、死亡
# 外文關鍵詞:
# Family relationship、Death、Cancer Bereaved Family
# 相關次數:
#
#
# 被引用:36點閱:2231評分:下載:709書目收藏:11
#
#
# 永久網址： https://hdl.handle.net/11296/7wjndw
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 江佩穎
# 研究生(外文):
# Pei-ying Chiang
# 論文名稱:
# 憲政體制與台、芬政府組成－比較研究途徑
# 論文名稱(外文):
# GOVERNMENT FORMATION IN TAIWAN AND FINLAND:A COMPARATIVE APPROACH
# 指導教授:
# 林水波
# 指導教授(外文):
# Shoei-po Lin
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 政治學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2007
# 畢業學年度:
# 95
# 語文別:
# 中文
# 論文頁數:
# 334
# 中文關鍵詞:
# 政府組成、政府終結、半總統制
# 外文關鍵詞:
# government formation、government termination、semi-presidentialism
# 相關次數:
#
#
# 被引用:0點閱:603評分:下載:136書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/c7923k
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 洪惠芬
# 研究生(外文):
# Huifen Hung
# 論文名稱:
# 工作、照顧與依賴：對福利國家與其當代危機的再省思
# 論文名稱(外文):
# Work, Care giving, and Dependency:A Reflection on Welfare State and its Contemporary Crisis
# 指導教授:
# 張震東
# 學位類別:
# 博士
# 校院名稱:
# 國立中正大學
# 系所名稱:
# 社會福利所
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 畢業學年度:
# 93
# 語文別:
# 中文
# 論文頁數:
# 199
# 中文關鍵詞:
# 工作福利、福利國家、福利依賴、新保守主義、照顧
# 外文關鍵詞:
# welfare state、welfare dependency、neo-conservatism、workfare、care giving.
# 相關次數:
#
#
# 被引用:12點閱:1289評分:下載:439書目收藏:6
#
#
# 永久網址： https://hdl.handle.net/11296/48w3xq
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 謝聖哲
# 研究生(外文):
# Sheng-Jer Hsieh
# 論文名稱:
# 一九九○年代台灣能障礙老人的家庭照顧之影響因素及其變遷
# 論文名稱(外文):
# The Influencing Factors and Changes of Family Caregivng for the Functionally Disabled Elderly in 1990s Taiwan
# 指導教授:
# 鄭文輝
# 指導教授(外文):
# Wen-Hwei Cheng
# 學位類別:
# 博士
# 校院名稱:
# 國立中正大學
# 系所名稱:
# 社會福利所
# 學門:
# 社會服務學門
# 學類:
# 社會工作學類
# 論文出版年:
# 2005
# 畢業學年度:
# 93
# 語文別:
# 中文
# 論文頁數:
# 103
# 中文關鍵詞:
# 照顧安排、家庭照顧、老人照顧、能障礙、照顧資源
# 外文關鍵詞:
# eldercare、family caregiving、care arrangement、functional disability、caretaker pool
# 相關次數:
#
#
# 被引用:2點閱:361評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/u3k5fq
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 丁榮轟
# 研究生(外文):
# Long-Hong Ting
# 論文名稱:
# 我國犯罪矯正機構實施空中大學矯正教育對出獄人生活適應之研究
# 論文名稱(外文):
# A Study on Life Adaptability and Open University Education for Former Inmates in Correctional Institutions in Taiwan
# 指導教授:
# 吳芝儀、蔡德輝
# 學位類別:
# 博士
# 校院名稱:
# 國立中正大學
# 系所名稱:
# 犯罪防治所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 畢業學年度:
# 93
# 語文別:
# 中文
# 論文頁數:
# 336
# 中文關鍵詞:
# 矯正機構、矯正教育、出獄人、再犯可能性、生活適應
# 外文關鍵詞:
# correction institution、life adaptability、correctional education、recidivism
# 相關次數:
#
#
# ...
# 研究生:
# 王玲敏
# 研究生(外文):
# Ling-Min Wang
# 論文名稱:
# 從府際關係理論析論美國與台灣教育事務權限劃分及運作
# 論文名稱(外文):
# A Study of Distribution and Operation of Educational Administration Authority in the U.S.A. and the R.O.C. Based on Intergovernmental Relations Theory
# 指導教授:
# 蔡政文
# 指導教授(外文):
# Tsai Cheng-wen
# 學位類別:
# 博士
# 校院名稱:
# 淡江大學
# 系所名稱:
# 美國研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 區域研究學類
# 論文出版年:
# 2004
# 畢業學年度:
# 92
# 語文別:
# 中文
# 論文頁數:
# 269
# 中文關鍵詞:
# 府際關係、教育改革、教育行政、分權管理
# 外文關鍵詞:
# decentralization、educational administration、educational reform
# 相關次數:
#
#
# 被引用:6點閱:498評分:下載:121書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/6hrwj3
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 謝立功
# 研究生(外文):
# Xie, Li-Gong
# 論文名稱:
# 洗錢防制與經濟法秩序之維護
# 論文名稱(外文):
# The Money Laundering Control Act:Along with other laws/acts dealing with criminal activity
# 指導教授:
# 陳志龍
# 指導教授(外文):
# Chen, Zhi-Long
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣大學
# 系所名稱:
# 三民主義研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 1998
# 畢業學年度:
# 86
# 語文別:
# 中文
# 論文頁數:
# 119
# 中文關鍵詞:
# 洗錢防制、經濟法、秩序維護、洗錢防制法、洗錢犯罪、重大犯罪、競合、經濟法秩序、三民主義、思想學、哲學
# 外文關鍵詞:
# money laundering、the Money Laundering Control Act、severe crimes、THREE-PRINCIPLE-OF-THE-PEOPLE、THINKING、PHILOSOPHY
# 相關次數:
#
#
# 被引用:10點閱:742評分:下載:0書目收藏:3
#
#
# 永久網址： https://hdl.handle.net/11296/t24y9a
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 蔡清遊
# 論文名稱:
# 刑事訴訟上當事人主義之研究
# 指導教授:
# 林國賢
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 中山學術研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2000
# 畢業學年度:
# 88
# 語文別:
# 中文
# 論文頁數:
# 507
# 中文關鍵詞:
# 當事人主義
# 相關次數:
#
#
# 被引用:14點閱:262評分:下載:0書目收藏:2
#
#
# 永久網址： https://hdl.handle.net/11296/5675e6
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 李建興
# 研究生(外文):
# Jen-Sin Lee
# 論文名稱:
# 貨幣需求結構改變與金融變數轉折區間：變數模糊時間序列模型
# 論文名稱(外文):
# Testing for the Financial variable’s Interval of Structure Change of Money Demand : Fuzzy Time Series in Variable
# 指導教授:
# 沈中華、李紀珠
# 指導教授(外文):
# Chung-Hua Shen、Jih-Chu Lee
# 學位類別:
# 博士
# 校院名稱:
# 國立政治大學
# 系所名稱:
# 中山人文社會科學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 2000
# 畢業學年度:
# 88
# 語文別:
# 中文
# 論文頁數:
# 138
# 中文關鍵詞:
# 結構改變、門檻轉折模型、模糊時間序列、變數模糊時間序列、平滑轉折模型
# 外文關鍵詞:
# Structural Change、Threshold Autoregressive、Fuzzy Time Series、Fuzzy Time Series in Variable、Smooth Transition Autoregressive
# 相關次數:
#
#
# 被引用:9點閱:472評分:下載:0書目收藏:4
#
#
# 永久網址： https://hdl.handle.net/11296/gmm6tt
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 王春源
# 論文名稱:
# 小型開放經濟之貶值效果:失衡模型分析
# 指導教授:
# 陳昭南、麥朝成、梁明義
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣大學
# 系所名稱:
# 經濟學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 1982
# 畢業學年度:
# 71
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:0點閱:95評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/948s48
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 蕭峰雄
# 論文名稱:
# 產業及技術選擇與工業發展:我國紡織工業之個案研究
# 指導教授:
# 吳榮義、劉泰英、李庸三
# 學位類別:
# 博士
# 校院名稱:
# 中國文化大學
# 系所名稱:
# 經濟研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 1982
# 畢業學年度:
# 71
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:2點閱:127評分:下載:0書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/3a6k9n
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 賴景昌
# 論文名稱:
# 匯率調整、理性預期、與國外干擾:兩國模型的探討
# 指導教授:
# 陳昭南、陳師孟、曹添旺
# 學位類別:
# 博士
# 校院名稱:
# 國立臺灣大學
# 系所名稱:
# 經濟學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 1983
# 畢業學年度:
# 72
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:3點閱:202評分:下載:0書目收藏:1
#
#
# 永久網址： https://hdl.handle.net/11296/7s478p
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 仉桂美
# 研究生(外文):
# Chang, Kuei-Mei
# 論文名稱:
# 我國各級政府間行政監督之研究
# 論文名稱(外文):
# The study of Administration Supervision in Intergovernmental Relations in R.O.C
# 指導教授:
# 張治安先生、薄慶玖先生
# 指導教授(外文):
# Chang, Chih-An、Po, Ching-Chiu
# 學位類別:
# 博士
# 校院名稱:
# 國立政治大學
# 系所名稱:
# 政治學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 1994
# 畢業學年度:
# 82
# 語文別:
# 中文
# 中文關鍵詞:
# 各級政府間之關係、地方政府、集權和分權、權與責、行政監督
# 外文關鍵詞:
# intergovernmental relations、local government
# 相關次數:
#
#
# 被引用:14點閱:178評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/sa7rt3
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 程長志
# 論文名稱:
# 中共談判行為研究--國共、中(共)英、中(共)葡個案分析
# 指導教授:
# 蔡政文、林碧炤、趙明義
# 指導教授(外文):
# Chen,Bao-Ji、SHEN,Tian-Fuh、Yu, Su-May
# 學位類別:
# 博士
# 校院名稱:
# 政治作戰學校
# 系所名稱:
# 政治研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 政治學類
# 論文出版年:
# 1994
# 畢業學年度:
# 82
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:5點閱:137評分:下載:0書目收藏:2
#
#
# 永久網址： https://hdl.handle.net/11296/q89kys
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 徐芳霞
# 論文名稱:
# 二分化市場結構下的關稅調降效果:臺灣狀況之一般均衡分析
# 指導教授:
# 朱雲鵬、王連常福、周添城
# 指導教授(外文):
# Mr. Tsay、Mr. Lin、D. R. Huang
# 學位類別:
# 博士
# 校院名稱:
# 國立中興大學
# 系所名稱:
# 經濟學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 1995
# 畢業學年度:
# 83
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:2點閱:73評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/22sbva
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃博怡
# 論文名稱:
# 清末民初中國銀錢業恐慌問題分析
# 指導教授:
# 梁發進、吳榮義、林向愷
# 指導教授(外文):
# Mr. Tsay、Mr. Lin、D. R. Huang
# 學位類別:
# 博士
# 校院名稱:
# 國立中興大學
# 系所名稱:
# 經濟學研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 經濟學類
# 論文出版年:
# 1995
# 畢業學年度:
# 83
# 語文別:
# 中文
# 相關次數:
#
#
# 被引用:0點閱:107評分:下載:0書目收藏:0
#
#
# 永久網址： https://hdl.handle.net/11296/3qqhbk
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 王明輝
# 研究生(外文):
# Wang, Ming-huei
# 論文名稱:
# 從「經濟世界」的觀點論兩岸三邊經貿互動的發展與限制
# 論文名稱(外文):
# The Development and the Limits of the Triangle Trading among Taiwan, Mainland China and Hong Kong: A Perspective of 「World- Economy」
# 指導教授:
# 高承恕、葉啟政、王永昌、張維安、陳介玄
# 指導教授(外文):
# Kao Cheng-shu、Yeh Chi-jeng、Wang Yung-chang、Chang Wei-an、Cheng Chieh-hsuan
# 學位類別:
# 博士
# 校院名稱:
# 東海大學
# 系所名稱:
# 社會學系
# 學門:
# 社會及行為科學學門
# 學類:
# 社會學類
# 論文出版年:
# 1996
# 畢業學年度:
# 84
# 語文別:
# 中文
# 論文頁數:
# 201
# 中文關鍵詞:
# 經濟世界、經濟連貫性、經濟層級、多元層級的社會
# 外文關鍵詞:
# world-economy、economic coherence、economic hiarachy、society: a set of set
# 相關次數:
#
#
# 被引用:0點閱:215評分:下載:0書目收藏:3
#
#
# 永久網址： https://hdl.handle.net/11296/2mmbs5
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 鄧煌發
# 研究生(外文):
# Huang-Fa Teng
# 論文名稱:
# 國中生輟學成因及其與偏差行為相關性之研究
# 論文名稱(外文):
# Causes of Dropouts and Relations Between Dropouts and deviant Behaviors: An Empirical Study in Taiwan
# 指導教授:
# 蔡德輝、張平吾
# 指導教授(外文):
# Te-hui Tsai、Ping-wu Chang
# 學位類別:
# 博士
# 校院名稱:
# 中央警察大學
# 系所名稱:
# 犯罪防治研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2001
# 畢業學年度:
# 89
# 語文別:
# 中文
# 論文頁數:
# 411
# 中文關鍵詞:
# 輟學、偏差行為、不穩定就學行為、社會鉅觀因素、社會微觀因素、拔河理論
# 外文關鍵詞:
# dropout、deviant behavior、unstable studying experience、social macro- factors、social micro- factors、theory of tug of war
# 相關次數:
#
#
# 被引用:87點閱:1071評分:下載:0書目收藏:22
#
#
# 永久網址： https://hdl.handle.net/11296/hjy96x
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 廖有祿
# 研究生(外文):
# Liao, You-lu
# 論文名稱:
# 電腦犯罪模式及犯罪者特徵分析之研究
# 論文名稱(外文):
# Analysis of Computer Crime Pattern and Criminal Characteristics
# 指導教授:
# 林燦璋、張平吾
# 指導教授(外文):
# Lin, Tsan-chang、Chang, Ping-wu
# 學位類別:
# 博士
# 校院名稱:
# 中央警察大學
# 系所名稱:
# 犯罪防治研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2001
# 畢業學年度:
# 89
# 語文別:
# 中文
# 論文頁數:
# 245
# 中文關鍵詞:
# 電腦犯罪、網路犯罪、犯罪剖繪、犯罪手法、犯罪簽名特徵、心理跡證、動機模型
# 外文關鍵詞:
# Computer Crime、Cyber Crime、Criminal Profiling、Modus Operandi、Crime Signature、Psychological Trail、Motivational Model
# 相關次數:
#
#
# 被引用:29點閱:848評分:下載:27書目收藏:7
#
#
# 永久網址： https://hdl.handle.net/11296/uj3fmw
# ========================================================================================
# 本論文永久網址:
#  複製永久網址var clipboard = new Clipboard('.btncopy'); (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));  {lang: "zh-TW"}   !function(d,s,id){ var js,fjs=d.getElementsByTagName(s)[0]; if(!d.getElementById(id)){ js=d.createElement(s);js.id=id; js.src="//platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js,fjs); }}(document,"script","twitter-wjs"); Twitter
# 研究生:
# 黃翠紋
# 論文名稱:
# 婚姻暴力調解措施之研究
# 指導教授:
# 許春金、張平吾、鄧學仁
# 學位類別:
# 博士
# 校院名稱:
# 中央警察大學
# 系所名稱:
# 犯罪防治研究所
# 學門:
# 社會及行為科學學門
# 學類:
# 綜合社會及行為科學學類
# 論文出版年:
# 2001
# 畢業學年度:
# 89
# 語文別:
# 中文
# 論文頁數:
# 262
# 中文關鍵詞:
# 婚姻暴力、調解措施、受虐婦女、保護令
# 相關次數:
#
#
# 被引用:54點閱:1009評分:下載:0書目收藏:16
#
#
# 永久網址： https://hdl.handle.net/11296/n3wr35
# ========================================================================================

# %%
df = pd.concat(df, ignore_index=True)
print(df.shape)
df

# %%
df.info()

# %%
df.to_pickle('./博碩士論文.pickle')
df.to_excel('./博碩士論文.xlsx')

# %%
tmp = df2.groupby(['校院名稱','系所名稱','學類','學門']).size().reset_index()
tmp.columns = ['學類', '學門', '校院名稱', '系所名稱', '則數']
tmp.to_excel('校系學門學類.xlsx')
