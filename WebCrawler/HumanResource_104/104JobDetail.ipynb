# %%
import requests
import pandas as pd
import time 
import re
import pickle
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
         'Referer': 'https://www.104.com.tw/',
         'Host': 'www.104.com.tw',
         'DNT':'1',
         'Cookie':'GoogleBot'}
#          'Cookie': "luauid=1226038844; __auc=e89875691740ad8d44e39419826; _hjid=a0b33d94-38d0-4a09-9258-eb6e772f5135; ALGO_EXP_6019=A; bprofile_history=%5B%7B%22key%22%3A%22ckirulc%22%2C%22custName%22%3A%22(city'super)%E9%81%A0%E6%9D%B1%E9%83%BD%E6%9C%83%E8%82%A1%E4%BB%BD%E6%9C%89%E9%99%90%E5%85%AC%E5%8F%B8%22%2C%22custLink%22%3A%22https%3A%2F%2Fwww.104.com.tw%2Fcompany%2Fckirulc%22%7D%5D; cust_same_ab=1; job_same_ab=2; _gaexp=GAX1.3.JA0tMycRRhS-5EjRcXg0uA.18521.1!TR-R_HpzRVS6WpOAaNbMWA.18521.0!ydox8u6PTwaYoX5PSnzxXA.18578.6; __asc=d02c7f2117413902e54cb1c07e2; _gid=GA1.3.92133915.1598056051; TS016ab800=01180e452d5356276b167d1832b5f52b3448d945385162661cbb8bb3778aa830eb6df9b74864ecdc0fee3cc38a423c61d34ad7e4bee8333ba5b9a6d8649a276cb57f4482fa136bfb852d75f4f41b84beda91443642890c6fd768d55ef3fcc9bc3336b265e3; _ga_W9X1GB1SVR=GS1.1.1598056050.3.1.1598057291.59; _ga_FJWMQR9J2K=GS1.1.1598056050.3.1.1598057292.0; _ga=GA1.3.55480194.1597909817; _dc_gtm_UA-15276226-1=1; _gat=1; lup=1226038844.5035849152215.4623532291991.1.4640712161167; lunp=4623532291991'"}

# %% [markdown]
# # 查詢地區號碼

# %%
url = 'https://static.104.com.tw/category-tool/json/Area.json'
resp = requests.get(url)
df1 = []
for i in resp.json()[0]['n']:
    ndf = pd.DataFrame(i['n'])
    ndf['city'] = i['des']
    df1.append(ndf)
df1=pd.concat(df1, ignore_index=True)
df1 = df1.loc[:,['city','des','no']]
df1 = df1.sort_values('no')
df1
# Out:
#     city     des          no
# 0    台北市  台北市中正區  6001001001
# 1    台北市  台北市大同區  6001001002
# 2    台北市  台北市中山區  6001001003
# 3    台北市  台北市松山區  6001001004
# 4    台北市  台北市大安區  6001001005
# ..   ...     ...         ...
# 360  金門縣  金門縣烏坵鄉  6001022006
# 361  連江縣  連江縣南竿鄉  6001023001
# 362  連江縣  連江縣北竿鄉  6001023002
# 363  連江縣  連江縣莒光鄉  6001023003
# 364  連江縣  連江縣東引鄉  6001023004
#
# [365 rows x 3 columns]

# %% [markdown]
# # 職缺清單

# %% [markdown]
# ## 數據分析

# %%
for p

# %%
keyword = '數據分析'
jobs = []

for area in df1['no']:
    page = 1
    print('Area:',area)
    print('Job Counts:', len(jobs))
    while True:
        try:            
            url = 'https://www.104.com.tw/jobs/search/list?ro=1&kwop=7&keyword={}&jobcatExpansionType=1&area={}&order=12&asc=0&page={}&mode=s&jobsource=2018indexpoc'.format(keyword, area, page)
            resp = requests.get(url,headers=headers)
            for job in resp.json()['data']['list']:
                jobs.append(job['link']['job'])
            if len(resp.json()['data']['list'])<20:
                break
            page += 1
        except:
            print('Retry')

jobs = list(set(jobs))
# Out:
# Area: 6001001001
# Job Counts: 0
# Area: 6001001002
# Job Counts: 465
# Area: 6001001003
# Job Counts: 611
# Area: 6001001004
# Job Counts: 1451
# Area: 6001001005
# Job Counts: 2134
# Area: 6001001006
# Job Counts: 2922
# Area: 6001001007
# Job Counts: 2957
# Area: 6001001008
# Job Counts: 3740
# Area: 6001001009
# Job Counts: 3832
# Area: 6001001010
# Job Counts: 3914
# Area: 6001001011
# Job Counts: 4719
# Area: 6001001012
# Job Counts: 5002
# Area: 6001002001
# Job Counts: 5032
# Area: 6001002002
# Job Counts: 5042
# Area: 6001002003
# Job Counts: 5049
# Area: 6001002004
# Job Counts: 5226
# Area: 6001002005
# Job Counts: 5391
# Area: 6001002006
# Job Counts: 5404
# Area: 6001002007
# Job Counts: 5411
# Area: 6001002008
# Job Counts: 5420
# Area: 6001002009
# Job Counts: 5425
# Area: 6001002010
# Job Counts: 5428
# Area: 6001002011
# Job Counts: 5436
# Area: 6001002012
# Job Counts: 5619
# Area: 6001002013
# Job Counts: 5626
# Area: 6001002014
# Job Counts: 5634
# ...

# %%
with open('DataAnalystic.pkl', 'wb') as f:
    pickle.dump(jobs, f)

# %% [markdown]
# ## 資料科學

# %%
keyword = '資料科學'
jobs = []

for area in df1['no']:
    page = 1
    print('Area:',area)
    print('Job Counts:', len(jobs))
    while True:
        try:            
            url = 'https://www.104.com.tw/jobs/search/list?ro=1&kwop=7&keyword={}&jobcatExpansionType=1&area={}&order=12&asc=0&page={}&mode=s&jobsource=2018indexpoc'.format(keyword, area, page)
            resp = requests.get(url,headers=headers)
            for job in resp.json()['data']['list']:
                jobs.append(job['link']['job'])
            if len(resp.json()['data']['list'])<20:
                break
            page += 1
        except:
            print('Retry')

jobs = list(set(jobs))
# Out:
# Area: 6001001001
# Job Counts: 0
# Area: 6001001002
# Job Counts: 12
# Area: 6001001003
# Job Counts: 20
# Area: 6001001004
# Job Counts: 35
# Area: 6001001005
# Job Counts: 57
# Area: 6001001006
# Job Counts: 85
# Area: 6001001007
# Job Counts: 92
# Area: 6001001008
# Job Counts: 135
# Area: 6001001009
# Job Counts: 142
# Area: 6001001010
# Job Counts: 153
# Area: 6001001011
# Job Counts: 183
# Area: 6001001012
# Job Counts: 195
# Area: 6001002001
# Job Counts: 210
# Area: 6001002002
# Job Counts: 210
# Area: 6001002003
# Job Counts: 210
# Area: 6001002004
# Job Counts: 218
# Area: 6001002005
# Job Counts: 231
# Area: 6001002006
# Job Counts: 231
# Area: 6001002007
# Job Counts: 231
# Area: 6001002008
# Job Counts: 231
# Area: 6001002009
# Job Counts: 231
# Area: 6001002010
# Job Counts: 231
# Area: 6001002011
# Job Counts: 231
# Area: 6001002012
# Job Counts: 242
# Area: 6001002013
# Job Counts: 242
# Area: 6001002014
# Job Counts: 242
# Area: 6001002015
# Job Counts: 249
# ...

# %%
with open('DataScience.pkl', 'wb') as f:
    pickle.dump(jobs, f)

# %% [markdown]
# ## 數據分析師

# %%
keyword = '數據分析師'
jobs = []

for area in df1['no']:
    page = 1
    print('Area:',area)
    print('Job Counts:', len(jobs))
    while True:
        try:            
            url = 'https://www.104.com.tw/jobs/search/list?ro=1&kwop=7&keyword={}&jobcatExpansionType=1&area={}&order=12&asc=0&page={}&mode=s&jobsource=2018indexpoc'.format(keyword, area, page)
            resp = requests.get(url,headers=headers)
            for job in resp.json()['data']['list']:
                jobs.append(job['link']['job'])
            if len(resp.json()['data']['list'])<20:
                break
            page += 1
        except:
            print('Retry')

jobs = list(set(jobs))
# Out:
# Area: 6001001001
# Job Counts: 0
# Area: 6001001002
# Job Counts: 152
# Area: 6001001003
# Job Counts: 178
# Area: 6001001004
# Job Counts: 452
# Area: 6001001005
# Job Counts: 740
# Area: 6001001006
# Job Counts: 986
# Area: 6001001007
# Job Counts: 1012
# Area: 6001001008
# Job Counts: 1316
# Area: 6001001009
# Job Counts: 1337
# Area: 6001001010
# Job Counts: 1359
# Area: 6001001011
# Job Counts: 1812
# Area: 6001001012
# Job Counts: 1928
# Area: 6001002001
# Job Counts: 1943
# Area: 6001002002
# Job Counts: 1943
# Area: 6001002003
# Job Counts: 1943
# Area: 6001002004
# Job Counts: 1975
# Area: 6001002005
# Job Counts: 2060
# Area: 6001002006
# Job Counts: 2075
# Area: 6001002007
# Job Counts: 2075
# Area: 6001002008
# Job Counts: 2075
# Area: 6001002009
# Job Counts: 2075
# Area: 6001002010
# Job Counts: 2075
# Area: 6001002011
# Job Counts: 2075
# Area: 6001002012
# Job Counts: 2116
# Area: 6001002013
# Job Counts: 2116
# Area: 6001002014
# Job Counts: 2116
# Area: 6001002015
# ...

# %%
with open('DataAnalystic2.pkl', 'wb') as f:
    pickle.dump(jobs, f)

# %% [markdown]
# ## 資料科學工程師

# %%
keyword = '資料科學工程師'
jobs = []

for area in df1['no']:
    page = 1
    print('Area:',area)
    print('Job Counts:', len(jobs))
    while True:
        try:            
            url = 'https://www.104.com.tw/jobs/search/list?ro=1&kwop=7&keyword={}&jobcatExpansionType=1&area={}&order=12&asc=0&page={}&mode=s&jobsource=2018indexpoc'.format(keyword, area, page)
            resp = requests.get(url,headers=headers)
            for job in resp.json()['data']['list']:
                jobs.append(job['link']['job'])
            if len(resp.json()['data']['list'])<20:
                break
            page += 1
        except:
            print('Retry')

jobs = list(set(jobs))
# Out:
# Area: 6001001001
# Job Counts: 0
# Area: 6001001002
# Job Counts: 454
# Area: 6001001003
# Job Counts: 647
# Area: 6001001004
# Job Counts: 1577
# Area: 6001001005
# Job Counts: 2326
# Area: 6001001006
# Job Counts: 3081
# Area: 6001001007
# Job Counts: 3124
# Area: 6001001008
# Job Counts: 4038
# Area: 6001001009
# Job Counts: 4099
# Area: 6001001010
# Job Counts: 4274
# Area: 6001001011
# Job Counts: 6298
# Area: 6001001012
# Job Counts: 6876
# Area: 6001002001
# Job Counts: 6897
# Area: 6001002002
# Job Counts: 6897
# Area: 6001002003
# Job Counts: 6897
# Area: 6001002004
# Job Counts: 7152
# Area: 6001002005
# Job Counts: 7522
# Area: 6001002006
# Job Counts: 7561
# Area: 6001002007
# Job Counts: 7568
# Area: 6001002008
# Job Counts: 7568
# Area: 6001002009
# Job Counts: 7568
# Area: 6001002010
# Job Counts: 7568
# Area: 6001002011
# Job Counts: 7568
# Area: 6001002012
# Job Counts: 7892
# Area: 6001002013
# Job Counts: 7892
# Area: 6001002014
# Job Counts: 7892
# ...

# %%
with open('DataEngineer.pkl', 'wb') as f:
    pickle.dump(jobs, f)

# %% [markdown]
# # 職缺內容

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36',
           'Referer': 'https://www.104.com.tw/'}

# %% [markdown]
# ## 數據分析

# %%
with open('DataAnalystic.pkl', 'rb') as f:
    jobs = pickle.load(f)

# %%
df = []
for i, job in enumerate(jobs):
    if i%100==0:
        print(i)
    url = 'https:' + job
    jobid = re.findall(r'job/([A-Za-z0-9]{1,})', url)[0]
    # 職缺內容
    url2 = 'https://www.104.com.tw/job/ajax/content/' + jobid
    resp = requests.get(url2, headers=headers)
    # 會有些異常的職缺沒有資料，同 try 函數 parse 資料
    try:
        data = resp.json()['data']
        ndf = pd.DataFrame([{'jobName':data['header']['jobName'], # 職缺名稱
                             'custName':data['header']['custName'], # 公司名稱
                             'custUrl':data['header']['custUrl'], # 公司網址
                             'jobDescription':data['jobDetail']['jobDescription'], # 工作內容
                             'specialty':', '.join([i['description'] for i in data['condition']['specialty']]), # 擅長工具
                             'skill':', '.join([i['description'] for i in data['condition']['skill']]), # 工作技能
                             'other': data['condition']['other'], # 其他條件
                             'workExp': data['condition']['workExp'], # 工作經歷
                             'edu': data['condition']['edu'], # 教育程度
                             'appearDate': data['header']['appearDate'], # 刊登日期
                             'addressRegion':data['jobDetail']['addressRegion'], # 工作地區
                             'addressDetail': data['jobDetail']['addressDetail'], # 工作地址
                             'longitude':data['jobDetail']['longitude'], # 地址經度
                             'latitude':data['jobDetail']['latitude'], # 地址緯度
                             'salary': data['jobDetail']['salary'],
                             'url':url
                            }])
        df.append(ndf)
    except:
        print(url2)
df=pd.concat(df, ignore_index=True)
df
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# url2
# 2100
# 2200
# 2300
# 2400
# url2
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# url2
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
#                                 jobName                            custName  \
# 0                             藝術精品 行銷業務                          八方新氣股份有限公司
# 1      產品行銷經理 Product Marketing Manager                            甲尚股份有限公司
# ...

# %%
df.to_pickle('DataAnalystic.pkl')

# %% [markdown]
# ## 資料科學

# %%
with open('DataScience.pkl', 'rb') as f:
    jobs = pickle.load(f)

# %%
df = []
for i, job in enumerate(jobs):
    if i%100==0:
        print(i)
    # 會有些異常的職缺沒有資料(如植入性廣告)，同 try 函數 parse 資料
    try:
        url = 'https:' + job
        jobid = re.findall(r'job/([A-Za-z0-9]{1,})', url)[0]
        # 職缺內容
        url2 = 'https://www.104.com.tw/job/ajax/content/' + jobid
        resp = requests.get(url2, headers=headers)
    
        data = resp.json()['data']
        ndf = pd.DataFrame([{'jobName':data['header']['jobName'], # 職缺名稱
                             'custName':data['header']['custName'], # 公司名稱
                             'custUrl':data['header']['custUrl'], # 公司網址
                             'jobDescription':data['jobDetail']['jobDescription'], # 工作內容
                             'specialty':', '.join([i['description'] for i in data['condition']['specialty']]), # 擅長工具
                             'skill':', '.join([i['description'] for i in data['condition']['skill']]), # 工作技能
                             'other': data['condition']['other'], # 其他條件
                             'workExp': data['condition']['workExp'], # 工作經歷
                             'edu': data['condition']['edu'], # 教育程度
                             'appearDate': data['header']['appearDate'], # 刊登日期
                             'addressRegion':data['jobDetail']['addressRegion'], # 工作地區
                             'addressDetail': data['jobDetail']['addressDetail'], # 工作地址
                             'longitude':data['jobDetail']['longitude'], # 地址經度
                             'latitude':data['jobDetail']['latitude'], # 地址緯度
                             'salary': data['jobDetail']['salary'],
                             'url':url
                            }])
        df.append(ndf)
    except:
        print(url)
df=pd.concat(df, ignore_index=True)
df
# Out:
# 0
# 100
# 200
# 300
# 400
# https://www.104.com.tw/job/ajax/content/4257l
# 500
# https://www.104.com.tw/job/ajax/content/6irj0
# 600
# 700
#                                            jobName  \
# 0    系統發展中心109年第三次專案(含定期契約)人力進用-15.研發類-品質工程/ 可靠度工程
# 1                                  (研發類)臨床試驗專員-ARS
# 2                                              護理師
# 3                                      短期(醫管部)藥局助理
# 4                                 CAE實習工讀生(宜蘭科學園區)
# ..                                             ...
# 703                                  英文特別助理/國際業務代表
# 704              國立中山大學海洋生物科技暨資源學系誠徵助理教授以上專任教師一至二名
# 705                     F16/QE - Big Data Engineer
# 706                                           銷售專員
# 707                                  商業分析人員(數據應用部)
#
#                                               custName  \
# 0                                            國家中山科學研究院
# 1                                           華廣生技股份有限公司
# ...

# %%
df.to_pickle('DataScience.pkl')

# %% [markdown]
# ## 數據分析師

# %%
with open('DataAnalystic2.pkl', 'rb') as f:
    jobs = pickle.load(f)

# %%
df = []
for i, job in enumerate(jobs):
    if i%100==0:
        print(i)
    # 會有些異常的職缺沒有資料(如植入性廣告)，同 try 函數 parse 資料
    try:
        url = 'https:' + job
        jobid = re.findall(r'job/([A-Za-z0-9]{1,})', url)[0]
        # 職缺內容
        url2 = 'https://www.104.com.tw/job/ajax/content/' + jobid
        resp = requests.get(url2, headers=headers)
    
        data = resp.json()['data']
        ndf = pd.DataFrame([{'jobName':data['header']['jobName'], # 職缺名稱
                             'custName':data['header']['custName'], # 公司名稱
                             'custUrl':data['header']['custUrl'], # 公司網址
                             'jobDescription':data['jobDetail']['jobDescription'], # 工作內容
                             'specialty':', '.join([i['description'] for i in data['condition']['specialty']]), # 擅長工具
                             'skill':', '.join([i['description'] for i in data['condition']['skill']]), # 工作技能
                             'other': data['condition']['other'], # 其他條件
                             'workExp': data['condition']['workExp'], # 工作經歷
                             'edu': data['condition']['edu'], # 教育程度
                             'appearDate': data['header']['appearDate'], # 刊登日期
                             'addressRegion':data['jobDetail']['addressRegion'], # 工作地區
                             'addressDetail': data['jobDetail']['addressDetail'], # 工作地址
                             'longitude':data['jobDetail']['longitude'], # 地址經度
                             'latitude':data['jobDetail']['latitude'], # 地址緯度
                             'salary': data['jobDetail']['salary'],
                             'url':url
                            }])
        df.append(ndf)
    except:
        print(url2)
df=pd.concat(df, ignore_index=True)
df
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# https://www.104.com.tw/job/ajax/content/452uu
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# https://www.104.com.tw/job/ajax/content/6irj0
# 3400
# 3500
#                      jobName                  custName  \
# 0                    SA系統分析師                  海棠設計有限公司
# 1     系統分析師_ASP.NET(C#)_102C           金財通商務科技服務股份有限公司
# 2              國內業務開發人員(台南區)                凱立開發實業有限公司
# 3                     市場分析人員                  創新生技有限公司
# 4                    系統開發工程師              華德動能科技股份有限公司
# ...                      ...                       ...
# 3504    YouBike-台中-資訊創新研發工程師  捷安特 YouBike_巨大機械工業股份有限公司
# 3505                 MIS工程師1                研能科技股份有限公司
# 3506               營運部-營運分析師                菜蟲農食股份有限公司
# 3507              銷售服務專員-竹苗區                德怡科技股份有限公司
# ...

# %%
df.to_pickle('DataAnalystic2.pkl')

# %% [markdown]
# ## 資料科學工程師

# %%
with open('DataEngineer.pkl', 'rb') as f:
    jobs = pickle.load(f)

# %%
df = []
for i, job in enumerate(jobs):
    if i%100==0:
        print(i)
    # 會有些異常的職缺沒有資料(如植入性廣告)，同 try 函數 parse 資料
    try:
        url = 'https:' + job
        jobid = re.findall(r'job/([A-Za-z0-9]{1,})', url)[0]
        # 職缺內容
        url2 = 'https://www.104.com.tw/job/ajax/content/' + jobid
        resp = requests.get(url2, headers=headers)
    
        data = resp.json()['data']
        ndf = pd.DataFrame([{'jobName':data['header']['jobName'], # 職缺名稱
                             'custName':data['header']['custName'], # 公司名稱
                             'custUrl':data['header']['custUrl'], # 公司網址
                             'jobDescription':data['jobDetail']['jobDescription'], # 工作內容
                             'specialty':', '.join([i['description'] for i in data['condition']['specialty']]), # 擅長工具
                             'skill':', '.join([i['description'] for i in data['condition']['skill']]), # 工作技能
                             'other': data['condition']['other'], # 其他條件
                             'workExp': data['condition']['workExp'], # 工作經歷
                             'edu': data['condition']['edu'], # 教育程度
                             'appearDate': data['header']['appearDate'], # 刊登日期
                             'addressRegion':data['jobDetail']['addressRegion'], # 工作地區
                             'addressDetail': data['jobDetail']['addressDetail'], # 工作地址
                             'longitude':data['jobDetail']['longitude'], # 地址經度
                             'latitude':data['jobDetail']['latitude'], # 地址緯度
                             'salary': data['jobDetail']['salary'],
                             'url':url
                            }])
        df.append(ndf)
    except:
        print(url2)
df=pd.concat(df, ignore_index=True)
df
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# https://www.104.com.tw/job/ajax/content/5t4z2
# 2900
# 3000
# https://www.104.com.tw/job/ajax/content/70668
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# https://www.104.com.tw/job/ajax/content/70bs5
# 4100
# 4200
# https://www.104.com.tw/job/ajax/content/4awk5
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# https://www.104.com.tw/job/ajax/content/4mdeu
# 10500
# 10600
# 10700
# 10800
# ...

# %%
df.to_pickle('DataEngineer.pkl')

# %% [markdown]
# ## 讀取資料

# %%
import pandas as pd

# %%
df = pd.read_pickle('DataAnalystic2_數據分析師.pkl')
df.shape
# Out:
# (3509, 16)

# %%
df = pd.read_pickle('DataAnalystic_數據分析.pkl')
df.shape
# Out:
# (10534, 16)

# %%
df = pd.read_pickle('DataEngineer_資料科學工程師.pkl')
df.shape
# Out:
# (13944, 16)

# %%
df = pd.read_pickle('DataScience_資料科學.pkl')
df
# Out:
#                                            jobName  \
# 0    系統發展中心109年第三次專案(含定期契約)人力進用-15.研發類-品質工程/ 可靠度工程
# 1                                  (研發類)臨床試驗專員-ARS
# 2                                              護理師
# 3                                      短期(醫管部)藥局助理
# 4                                 CAE實習工讀生(宜蘭科學園區)
# ..                                             ...
# 703                                  英文特別助理/國際業務代表
# 704              國立中山大學海洋生物科技暨資源學系誠徵助理教授以上專任教師一至二名
# 705                     F16/QE - Big Data Engineer
# 706                                           銷售專員
# 707                                  商業分析人員(數據應用部)
#
#                                               custName  \
# 0                                            國家中山科學研究院
# 1                                           華廣生技股份有限公司
# 2                                               行健骨科診所
# 3                                           科達製藥股份有限公司
# 4                                           鑫威資訊股份有限公司
# ...
