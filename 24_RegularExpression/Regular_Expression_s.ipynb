# %% [markdown]
# # Regular Expression
# - 游騰林(tlyu0419)
# - 2023-3-28
# - Mail: tlyu0419@gmail.com

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Load data
# - 讀取 excel 的資料
#   - https://github.com/tlyu0419/DataScience/tree/master/24_RegularExpression
# - 去除商品名稱(prodname)為空的資料

# %%
# Out:
# (8122, 5)
#   channel                                 prodname  \
# 0  pchome         米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1  pchome      【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2  pchome  普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
#
#                                          description    price  \
# 0  米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# 1  米其林 PRIMACY SUV 225-65-17寧靜舒適輪胎四入組 ☆歡慶開館☆限時加碼送...  17400.0
# 2  普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎 卓越的乘坐舒...  13000.0
#
#                                               link
# 0  https://24h.pchome.com.tw/prod/QCBC06-A900AL07Z
# 1  https://24h.pchome.com.tw/prod/QCBC06-A900A0SB6
# 2  https://24h.pchome.com.tw/prod/QCBC0A-A900AM18A

# %% [markdown]
# ## prod_brand
# 已知各大品牌的輪胎有以下名稱，請撰寫一個 function 判斷輪胎的製造商。若非一下品牌或比對不到時則會回傳 np.nan
# - Michelin: Michelin，米其林
# - Continental: Continental，馬牌
# - GOODYEAR: GOODYEAR，固特異
# - FALKEN: FALKEN，飛隼
# - DUNLOP: DUNLOP， 登祿普， 登陸普
# - PIRELLI: PIRELLI|倍耐力
# - Bridgestone: BRIDGESTONE|普利司通

# %%
def check_prod_brand(prod):

  return prod

# %%
# 輪胎品牌
df['brand'] = df['prodname'].apply(lambda x: check_prod_brand(x))
df.loc[df['brand'].isnull()]
# Out:
#      channel                                           prodname  \
# 15    pchome                     南港輪胎 SP-9 235-55-18 (4入組)安靜耐磨胎
# 22    pchome              Nitto日東輪胎 NT421Q 225-65-17(2入組)超寧靜休旅胎
# 23    pchome                東洋輪胎 PROXES CR1 195-50-16(4組入)寧靜舒適胎
# 29    pchome                東洋輪胎 PROXES CR1 205-60-16(4組入)寧靜舒適胎
# 32    pchome   【MINERVA】F205 米納瓦低噪排水運動操控轎車輪胎 四入組 235/35/19(安托華)
# ...      ...                                                ...
# 7950  friday       【FIREMAX 福麥斯】FM601 91W 215/45/17_二入組 輪胎(車麗屋)
# 7959  friday       【FIREMAX 福麥斯】FM601 91W 215/45/17_四入組 輪胎(車麗屋)
# 7962  friday       【FIREMAX 福麥斯】FM601 98W 235/45/18_四入組 輪胎(車麗屋)
# 8068  friday  【FIREMAX】FIREMAX舒適寧靜輪胎FM601-225/40/18 四入組 (適用於...
# 8123  friday  【FIREMAX】FM601 降噪耐磨輪胎_四入組_225/45/17(適用Camry.Mo...
#
#                                             description    price  \
# 15    南港輪胎 SP-9 235-55-18 (4入組)安靜耐磨胎 安靜 耐磨 \n■寬大的四條直...  16500.0
# ...

# %%
df['brand'].value_counts()
# Out:
# Michelin       2240
# Continental    1616
# GOODYEAR       1037
# FALKEN          564
# DUNLOP          520
# PIRELLI         469
# Bridgestone     381
# Name: brand, dtype: int64

# %% [markdown]
# ## prod_cnt
# 已知輪胎的數量有以下名稱，請撰寫一個 function 判斷輪胎的數量。若比對不到時則會回傳 4(預設值)
# - 4: 四入|4入|4組|４入
# - 2: 二入|2入|2組|兩入
# - 1: 一入

# %%
# 多少入
def check_prod_cnt(prod):

  return cnt

# %%
df['cnt'] = df['prodname'].apply(lambda x: check_prod_cnt(x))
df.loc[df['cnt'].isnull()]
# Out:
#        channel                              prodname  \
# 1534    pchome  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋)
# 1535    pchome  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋)
# 1536    pchome  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋)
# 1537    pchome  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋)
# 1538    pchome  【AutoSock】輪胎防滑雪套 autosock HP600(車麗屋)
# ...        ...                                   ...
# 7609  autobacs                      專業洗車九件組合包 FI-KIT
# 7610  autobacs                    SOFT99去小傷痕組合 09213
# 7612  autobacs              門栓水鑽 GS-DL01 / 施華洛世奇水鑽精品
# 7613  autobacs                            水垢去汙清潔D-47
# 7614  autobacs                     靜音計劃/隔音底漆/輪弧用2680
#
#                                             description   price  \
# 1534  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋) 無須定位校正，安裝...  3388.0
# 1535  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋) 無須定位校正，安裝...  3388.0
# 1536  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋) 無須定位校正，安裝...  3388.0
# 1537  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋) 無須定位校正，安裝...  3388.0
# ...

# %%
df.loc[df['cnt'].notnull()]
# Out:
#      channel                                           prodname  \
# 0     pchome                   米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome                【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome            普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome            米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome          普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                                ...
# 8120  friday        【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8123  friday  【FIREMAX】FM601 降噪耐磨輪胎_四入組_225/45/17(適用Camry.Mo...
# 8124  friday         【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# ...

# %% [markdown]
# ## prod_speck
# 已知輪胎的規格有以下格式，請撰寫一個 function 判斷輪胎的規格。若比對不到時則回傳空值(np.nan)
# - 215-65-16
# - 215/65/16
# - 215/65-16
# - 215/65 R16
# - 165-R13
# - 185R14
# - 165/13
# - 2454520
# - 155R/13
# - 155-13

# %%
# 尺寸
def check_prod_speck(prod):

    return speck

# %%
df['speck'] = df['prodname'].apply(lambda x: check_prod_speck(x))
df.loc[df['speck'].isnull()]
# Out:
#        channel                              prodname  \
# 1534    pchome  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋)
# 1535    pchome  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋)
# 1536    pchome  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋)
# 1537    pchome  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋)
# 1538    pchome  【AutoSock】輪胎防滑雪套 autosock HP600(車麗屋)
# ...        ...                                   ...
# 7610  autobacs                    SOFT99去小傷痕組合 09213
# 7611  autobacs              裝飾貼GS-KL04 2入/ 施華洛世奇水鑽精品
# 7612  autobacs              門栓水鑽 GS-DL01 / 施華洛世奇水鑽精品
# 7613  autobacs                            水垢去汙清潔D-47
# 7614  autobacs                     靜音計劃/隔音底漆/輪弧用2680
#
#                                             description   price  \
# 1534  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋) 無須定位校正，安裝...  3388.0
# 1535  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋) 無須定位校正，安裝...  3388.0
# 1536  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋) 無須定位校正，安裝...  3388.0
# 1537  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋) 無須定位校正，安裝...  3388.0
# ...

# %%
df.loc[df['speck'].notnull()]
# Out:
#      channel                                           prodname  \
# 0     pchome                   米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome                【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome            普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome            米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome          普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                                ...
# 8120  friday        【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8123  friday  【FIREMAX】FM601 降噪耐磨輪胎_四入組_225/45/17(適用Camry.Mo...
# 8124  friday         【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# ...

# %% [markdown]
# ## prod_speck2
# 承上，客戶抱怨程式碼太冗長了，請我們將相似的規格合併在一起
# - 類型1: 215-65-16 or 215/65/16 or 215/65-16 or 215/65 R16 or 205/70R15
# - 類型2: 2454520
# - 類型3: 165-R13 or 185R14 or 155-13 or 165/13

# %%
# 尺寸
def check_prod_speck2(prod):

    return speck

# %%
df['speck2'] = df['prodname'].apply(lambda x: check_prod_speck2(x))
df.loc[df['speck2'].notnull()]
# Out:
#      channel                                           prodname  \
# 0     pchome                   米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome                【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome            普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome            米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome          普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                                ...
# 8120  friday        【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8123  friday  【FIREMAX】FM601 降噪耐磨輪胎_四入組_225/45/17(適用Camry.Mo...
# 8124  friday         【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# ...

# %%
df.loc[df['speck2'].isnull()].head()
# Out:
#      channel                              prodname  \
# 1534  pchome  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋)
# 1535  pchome  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋)
# 1536  pchome  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋)
# 1537  pchome  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋)
# 1538  pchome  【AutoSock】輪胎防滑雪套 autosock HP600(車麗屋)
#
#                                             description   price  \
# 1534  【AutoSock】輪胎防滑雪襪 autosock HP685(車麗屋) 無須定位校正，安裝...  3388.0
# 1535  【AutoSock】輪胎防滑雪襪 autosock HP697(車麗屋) 無須定位校正，安裝...  3388.0
# 1536  【AutoSock】輪胎防滑雪襪 autosock HP695(車麗屋) 無須定位校正，安裝...  3388.0
# 1537  【AutoSock】輪胎防滑雪襪 autosock HP645(車麗屋) 無須定位校正，安裝...  3388.0
# 1538  【AutoSock】輪胎防滑雪套 autosock HP600(車麗屋) 無須定位校正，安裝...  3388.0
#
#                                                  link brand  cnt speck speck2
# 1534  https://24h.pchome.com.tw/prod/DXBQ2J-A900G055P   NaN  NaN   NaN    NaN
# 1535  https://24h.pchome.com.tw/prod/DXBQ2J-A900G056R   NaN  NaN   NaN    NaN
# ...

# %% [markdown]
# ## prod_speck3
# 承上，規格中的 3 個數字依序代表輪胎的 寬度、扁平比 與 直徑，客戶請我們將抽取出的資料拆分成 3 個欄位

# %%
# 尺寸
def check_prod_speck3(prod):

    return width, aspect_ratio, diameter

# %%
# zip 中的 * 號的意義
df['width'], df['aspect_ratio'], df['diameter'] = zip(*df['prodname'].apply(lambda x: check_prod_speck3(x)))
df
# Out:
#      channel                                           prodname  \
# 0     pchome                   米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome                【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome            普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome            米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome          普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                                ...
# 8120  friday        【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday       【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8123  friday  【FIREMAX】FM601 降噪耐磨輪胎_四入組_225/45/17(適用Camry.Mo...
# 8124  friday         【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# ...

# %% [markdown]
# # 資料清理
# - 丟掉比不到製造商的商品
# - 丟掉不需要的欄位(speck)
# - 將 speck2 重新命名成 speck
# - 丟掉輪胎直徑為空值的資料
# - 計算輪胎的單價(總價(price) / 商品數量(cnt))

# %%
# Out:
#   channel                                   prodname  \
# 0  pchome           米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1  pchome        【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2  pchome    普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3  pchome    米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4  pchome  普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
#
#                                          description    price  \
# 0  米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# 1  米其林 PRIMACY SUV 225-65-17寧靜舒適輪胎四入組 ☆歡慶開館☆限時加碼送...  17400.0
# 2  普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎 卓越的乘坐舒...  13000.0
# 3  米其林 Energy Saver 4 205-55-16四入組省油耐磨輪胎 此優惠價格，不適...  14352.0
# 4  普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎 安靜省油...  12000.0
#
#                                               link        brand  cnt  \
# 0  https://24h.pchome.com.tw/prod/QCBC06-A900AL07Z     Michelin  4.0
# 1  https://24h.pchome.com.tw/prod/QCBC06-A900A0SB6     Michelin  4.0
# ...

# %% [markdown]
# # 分析

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(16, 8)})
sns.boxplot(x='brand', y='unit_price', hue='diameter', data=df)
# Out:
# <Axes: xlabel='brand', ylabel='unit_price'>

# %% [markdown]
# ## check_prod_speck4
# - 根據業務經驗，輪胎的直徑應介於 13-23寸，但分析時發現有輪胎的直徑高達60，顯然是在處理資料的過程中出錯了。
# - 嘗試將尺寸 24 以上的輪胎叫出來

# %%
# Out:
#        channel                                           prodname description  \
# 4625      car1       【BRIDGESTONE 普利司通】ALENZA 頂級舒適耐磨輪胎_235/45//18         NaN
# 7532  autobacs  PIRELLI 倍耐力輪胎 P7 BLUE – 225/55WR17 101W 靜音/舒適/...         NaN
# 7535  autobacs  PIRELLI 倍耐力輪胎 P6 – 185/60HR14 82H 節能/舒適/操控/低噪音...         NaN
# 7543  autobacs  PIRELLI 倍耐力輪胎 P7 BLUE – 245/40YR18 97Y 靜音/舒適/排...         NaN
# 7551  autobacs  PIRELLI 倍耐力輪胎 P7 BLUE – 225/50YR17 98Y 靜音/舒適/排...         NaN
#
#        price                                               link        brand  \
# 4625  4188.0        https://www.car1.com.tw/product-detail/6626  Bridgestone
# 7532  5598.0  https://www.autobacs.com.tw/product/2012345988...      PIRELLI
# 7535  2498.0  https://www.autobacs.com.tw/product/pirelli-p6...      PIRELLI
# 7543  6298.0  https://www.autobacs.com.tw/product/%e3%80%90%...      PIRELLI
# 7551  5698.0  https://www.autobacs.com.tw/product/2012345722...      PIRELLI
#
# ...

# %%
# Out:
# array(['【BRIDGESTONE 普利司通】ALENZA 頂級舒適耐磨輪胎_235/45//18',
#        'PIRELLI 倍耐力輪胎 P7 BLUE – 225/55WR17 101W 靜音/舒適/排水/操控/轎車胎 一入',
#        'PIRELLI 倍耐力輪胎 P6 – 185/60HR14 82H 節能/舒適/操控/低噪音/轎車胎 一入',
#        'PIRELLI 倍耐力輪胎 P7 BLUE – 245/40YR18 97Y 靜音/舒適/排水/操控/轎車胎 一入',
#        'PIRELLI 倍耐力輪胎 P7 BLUE – 225/50YR17 98Y 靜音/舒適/排水/操控/轎車胎 一入'],
#       dtype=object)

# %% [markdown]
# by domain 可以知道輪胎尺寸，所以正則要再調整一下，最後的數字為 '[1-2][0-9]', 不能直接 0-9 抓兩個數字

# %%
# 尺寸
def check_prod_speck4(prod):

    return width, aspect_ratio, diameter

# %%
df['width'], df['aspect_ratio'], df['diameter'] = zip(*df['prodname'].apply(lambda x: check_prod_speck4(x)))
df
# Out:
#      channel                                      prodname  \
# 0     pchome              米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome           【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome       普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome       米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome     普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                           ...
# 8119  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/17
# 8120  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8124  friday    【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# 1     米其林 PRIMACY SUV 225-65-17寧靜舒適輪胎四入組 ☆歡慶開館☆限時加碼送...  17400.0
# ...

# %%
# 還是會有誤抓的qq
df['diameter'].value_counts()
# Out:
# 18    1810
# 17    1545
# 16     982
# 19     937
# 15     699
# 20     441
# 14     231
# 21      95
# 13      64
# 22      13
# 10       2
# Name: diameter, dtype: int64

# %%
df.loc[df['diameter']=='10'][['prodname', 'diameter']].values
# Out:
# array([['【GOODYEAR 固特異】Cargo G26 102/100P 貨卡專用輪胎_185R/14', '10'],
#        ['【GOODYEAR 固特異】輪胎 Cargo G26 102/100P 貨卡專用輪胎_二入組_185R/14', '10']],
#       dtype=object)

# %% [markdown]
# ## check_prod_speck5
# - 要改成13-22

# %%
# 尺寸
def check_prod_speck5(prod):

    return width, aspect_ratio, diameter

# %%
df['width'], df['aspect_ratio'], df['diameter'] = zip(*df['prodname'].apply(lambda x: check_prod_speck5(x)))
df
# Out:
#      channel                                      prodname  \
# 0     pchome              米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome           【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome       普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome       米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome     普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                           ...
# 8119  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/17
# 8120  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8124  friday    【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# 1     米其林 PRIMACY SUV 225-65-17寧靜舒適輪胎四入組 ☆歡慶開館☆限時加碼送...  17400.0
# ...

# %%
# 終於正確了qq
df['diameter'].value_counts()
# Out:
# 18    1810
# 17    1545
# 16     982
# 19     937
# 15     699
# 20     441
# 14     233
# 21      95
# 13      64
# 22      13
# Name: diameter, dtype: int64

# %%
sns.set(rc={'figure.figsize':(16, 8)})
sns.boxplot(x='diameter', y='unit_price', hue='brand', data=df)
# Out:
# <Axes: xlabel='diameter', ylabel='unit_price'>

# %%
df
# Out:
#      channel                                      prodname  \
# 0     pchome              米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎
# 1     pchome           【米其林】PRIMACY SUV 225-65-17寧靜舒適輪胎四入組
# 2     pchome       普利司通輪胎 TURANZA ER33 215-55-17(４入組)卓越舒適胎
# 3     pchome       米其林 Energy Saver 4   205-55-16四入組省油耐磨輪胎
# 4     pchome     普利司通輪胎 ECOPIA NH100 195-65-15(４入組)耐磨神省能輪胎
# ...      ...                                           ...
# 8119  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/17
# 8120  friday   【德國馬牌】UltraContact UC6 舒適操控輪胎_二入組_235/55/18
# 8121  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/40/18
# 8122  friday  【FALKEN 飛隼】AZENIS FK510 濕地操控輪胎_二入組_225/45/17
# 8124  friday    【FALKEN 飛隼】ZE310 98W 全天候性能輪胎_四入組_215/55/17
#
#                                             description    price  \
# 0     米其林 PRIMACY 4 215-55-17四入組安靜舒適輪胎 此優惠價格，不適用米其林官...  17152.0
# 1     米其林 PRIMACY SUV 225-65-17寧靜舒適輪胎四入組 ☆歡慶開館☆限時加碼送...  17400.0
# ...

# %% [markdown]
# # 交卷

# %%
df.to_excel('./mich_tires_data.excel')
